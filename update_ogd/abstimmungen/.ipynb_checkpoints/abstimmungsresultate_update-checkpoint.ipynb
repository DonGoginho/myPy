# %% [markdown]
# # Update Abstimmungsresultate
# Datum: 28.11.2021
#
# Immer nach den Abstimmungen werden die Abstimmungsresultate vom Datamanagement aufbereitet und auf der «[**Abstimmungs-Datenbank
# von Statistik Stadt Zürich**](http://sszsttprd/statisticstools/Modules/Abstimmungen/Intranet/)» verfügbar gemacht.
#
# Für OGD kann dann via Exportfunktion (Format Roh > Export) ein Excelfile exportiert und unter folgendem Pfad abgelegt werden:
# `\\szh.loc\ssz\applikationen\OGD\Daten\Quelldaten\SSZ\Politik\abstimmungen\__Modules_Abstimmungen_Export_AbstimmungenExport.xls`
#
# Damit das die Ressourcen des Datasets «[Abstimmungsresultate der Stadt Zürich, seit 1933](https://data.stadt-zuerich.ch/dataset/politik-abstimmungen-seit-1933)» **manuell** aktualisiert werden können, muss das exportierte Excel noch
#  - als **Csv** aufbereitet und
#  - das Attribut 'Abstimmungs_Datum' noch ins korrekte Datumsformat (**JJJJ-MM-TT / ISO 8601**) umgewandelt
#  werden.
#
# Früher wurden diese simplen Schritte im Libre Office (Open Office) gemacht. Nun sollen sie noch einfacher per Python gemacht werden.
#
#
#
# <!---
# Dieses Notebook verwendet als Vorlage die Webseite «[Kitas in Berlin - Jupyter Notebook](https://juanitorduz.github.io/kitas_berlin/)»
# ---!>

# %%
#%pip install geopandas fiona requests folium mplleaflet contextily

# %%
import numpy as np
import pandas as pd
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui

# %% [markdown]
# ## Zuletzt veröffentlichte Abstimmungsresultate
# Wie sehen die aktuell auf dem OGD-Katalog veröffentlichten Daten dazu aus?

# %%
url_abstimmungsresultate =r"https://data.stadt-zuerich.ch/dataset/politik-abstimmungen-seit-1933/download/abstimmungen_seit1933.csv"

# Read the data
bisherige_abstimmungsresultate = pd.read_csv(
    url_abstimmungsresultate, 
    sep=','    
    )
bisherige_abstimmungsresultate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9850 entries, 0 to 9849
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Abstimmungs_Datum      9850 non-null   object
#  1   Nr_Politische_Ebene    9850 non-null   int64
#  2   Name_Politische_Ebene  9850 non-null   object
#  3   Abstimmungs_Text       9850 non-null   object
#  4   Nr_Resultat_Gebiet     9850 non-null   int64
#  5   Name_Resultat_Gebiet   9850 non-null   object
#  6   Nr_Wahlkreis_StZH      5255 non-null   float64
#  7   Name_Wahlkreis_StZH    5255 non-null   object
#  8   Stimmberechtigt        6710 non-null   float64
#  9   Ja                     9850 non-null   int64
#  10  Nein                   9850 non-null   int64
#  11  Stimmbeteiligung (%)   9850 non-null   float64
#  12  Ja (%)                 9850 non-null   float64
#  13  Nein (%)               9850 non-null   float64
#  14  StaendeJa              388 non-null    object
#  15  StaendeNein            392 non-null    object
# dtypes: float64(5), int64(4), object(7)
# memory usage: 1.2+ MB

# %%
bisherige_abstimmungsresultate.head(2)
# Out:
#   Abstimmungs_Datum  Nr_Politische_Ebene Name_Politische_Ebene  \
# 0        2022-02-13                    1     Eidgenossenschaft
# 1        2022-02-13                    1     Eidgenossenschaft
#
#                                     Abstimmungs_Text  Nr_Resultat_Gebiet  \
# 0  Volksinitiative «Ja zum Tier- und Menschenvers...                   1
# 1  Volksinitiative «Ja zum Tier- und Menschenvers...                   2
#
#   Name_Resultat_Gebiet  Nr_Wahlkreis_StZH Name_Wahlkreis_StZH  \
# 0    Eidgenossenschaft                NaN                 NaN
# 1        Kanton Zürich                NaN                 NaN
#
#    Stimmberechtigt      Ja     Nein  Stimmbeteiligung (%)  Ja (%)  Nein (%)  \
# 0              NaN  500937  1893539                  44.2    20.9      79.1
# 1         958009.0   90988   356755                  47.9    20.3      79.7
#
#   StaendeJa StaendeNein
# 0     0 0/2      20 6/2
# 1       NaN         NaN

# %% [markdown]
# ## Importiere die neusten Abstimmungsresultate zur Datenaufbereitung
#
# Wir importieren das von der Abstimmungsdatenbank exportierte Excelfile und bereiten es für die Veröffentlichung für OGD auf.

# %% [markdown]
# Link zu `read_excel()` in Pandas: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html
#
# `pandas.read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=None, mangle_dupe_cols=True, storage_options=None)`

# %%
# Filepath
fp = r"\\szh.loc\ssz\applikationen\OGD\Daten\Quelldaten\SSZ\Politik\abstimmungen\__Modules_Abstimmungen_Export_AbstimmungenExport.xls"

# Read the data
imp_abstimmungsresultate = pd.read_excel(
    io = fp, 
    parse_dates=True,
    dtype={'Abstimmungs_Text': str}
    )
imp_abstimmungsresultate.head()
# Out:
#   Abstimmungs_Datum  Nr_Politische_Ebene Name_Politische_Ebene  \
# 0        2022-02-13                    1     Eidgenossenschaft
# 1        2022-02-13                    1     Eidgenossenschaft
# 2        2022-02-13                    1     Eidgenossenschaft
# 3        2022-02-13                    1     Eidgenossenschaft
# 4        2022-02-13                    1     Eidgenossenschaft
#
#                                     Abstimmungs_Text  Nr_Resultat_Gebiet  \
# 0  Volksinitiative «Ja zum Tier- und Menschenvers...                   1
# 1  Volksinitiative «Ja zum Tier- und Menschenvers...                   2
# 2  Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 3  Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 4  Volksinitiative «Ja zum Tier- und Menschenvers...                   3
#
#   Name_Resultat_Gebiet  Nr_Wahlkreis_StZH Name_Wahlkreis_StZH  \
# 0    Eidgenossenschaft                NaN                 NaN
# 1        Kanton Zürich                NaN                 NaN
# 2         Stadt Zürich                NaN                 NaN
# 3         Stadt Zürich                2.0           Kreis 1+2
# 4         Stadt Zürich                3.0             Kreis 3
#
#    Stimmberechtigt      Ja     Nein  Stimmbeteiligung (%)  Ja (%)  Nein (%)  \
# 0              NaN  500937  1893539                  44.2    20.9      79.1
# 1         958009.0   90988   356755                  47.9    20.3      79.7
# 2         266675.0   25704    98575                  47.9    20.7      79.3
# 3          22746.0    2446     9537                  54.2    20.4      79.6
# 4          27831.0    2969    11343                  53.1    20.7      79.3
#
#   StaendeJa StaendeNein
# 0     0 0/2      20 6/2
# 1       NaN         NaN
# 2       NaN         NaN
# 3       NaN         NaN
# 4       NaN         NaN

# %%
imp_abstimmungsresultate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9850 entries, 0 to 9849
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Abstimmungs_Datum      9850 non-null   datetime64[ns]
#  1   Nr_Politische_Ebene    9850 non-null   int64
#  2   Name_Politische_Ebene  9850 non-null   object
#  3   Abstimmungs_Text       9850 non-null   object
#  4   Nr_Resultat_Gebiet     9850 non-null   int64
#  5   Name_Resultat_Gebiet   9850 non-null   object
#  6   Nr_Wahlkreis_StZH      5255 non-null   float64
#  7   Name_Wahlkreis_StZH    5255 non-null   object
#  8   Stimmberechtigt        6710 non-null   float64
#  9   Ja                     9850 non-null   int64
#  10  Nein                   9850 non-null   int64
#  11  Stimmbeteiligung (%)   9850 non-null   float64
#  12  Ja (%)                 9850 non-null   float64
#  13  Nein (%)               9850 non-null   float64
#  14  StaendeJa              388 non-null    object
#  15  StaendeNein            392 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(4), object(6)
# memory usage: 1.2+ MB

# %%
latest = imp_abstimmungsresultate.query("Abstimmungs_Datum == '2022-02-13'")
latest.head(3)
# Out:
#   Abstimmungs_Datum  Nr_Politische_Ebene Name_Politische_Ebene  \
# 0        2022-02-13                    1     Eidgenossenschaft
# 1        2022-02-13                    1     Eidgenossenschaft
# 2        2022-02-13                    1     Eidgenossenschaft
#
#                                     Abstimmungs_Text  Nr_Resultat_Gebiet  \
# 0  Volksinitiative «Ja zum Tier- und Menschenvers...                   1
# 1  Volksinitiative «Ja zum Tier- und Menschenvers...                   2
# 2  Volksinitiative «Ja zum Tier- und Menschenvers...                   3
#
#   Name_Resultat_Gebiet  Nr_Wahlkreis_StZH Name_Wahlkreis_StZH  \
# 0    Eidgenossenschaft                NaN                 NaN
# 1        Kanton Zürich                NaN                 NaN
# 2         Stadt Zürich                NaN                 NaN
#
#    Stimmberechtigt      Ja     Nein  Stimmbeteiligung (%)  Ja (%)  Nein (%)  \
# 0              NaN  500937  1893539                  44.2    20.9      79.1
# 1         958009.0   90988   356755                  47.9    20.3      79.7
# 2         266675.0   25704    98575                  47.9    20.7      79.3
#
#   StaendeJa StaendeNein
# 0     0 0/2      20 6/2
# 1       NaN         NaN
# 2       NaN         NaN

# %% [markdown]
# ## Gibt es beim Import Probleme?
# Damit sauber exportiert werden kann, müssen die Daten auch sauber eingelesen werden. Wie können wir das aber testen?
#
# Was sind die unique values per feature

# %%
imp_abstimmungsresultate.apply(lambda x: x.unique().size, axis=0)
# Out:
# Abstimmungs_Datum         417
# Nr_Politische_Ebene         3
# Name_Politische_Ebene       3
# Abstimmungs_Text         2509
# Nr_Resultat_Gebiet          3
# Name_Resultat_Gebiet        3
# Nr_Wahlkreis_StZH          17
# Name_Wahlkreis_StZH        17
# Stimmberechtigt          1196
# Ja                       8659
# Nein                     8283
# Stimmbeteiligung (%)     1582
# Ja (%)                    851
# Nein (%)                  851
# StaendeJa                  97
# StaendeNein                90
# dtype: int64

# %% [markdown]
# ## Speichere die neuen Resultate in ein OGD-konformes CSV-File
#
# OGD-konform bedeutet:
# - **Datenformat**: `CSV`,
# - **Encoding**: in `UTF8`,
# - **Strings**: Zwischen Anführungszeichen `""`
# - **Separator**: ` , `
#
# Link zu `to_csv()` in Pandas: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html
#
# DataFrame.to_csv(path_or_buf=None, sep=',', na_rep='', float_format=None, columns=None, header=True, index=True, index_label=None, mode='w', encoding=None, compression='infer', quoting=None, quotechar='"', line_terminator=None, chunksize=None, date_format=None, doublequote=True, escapechar=None, decimal='.', errors='strict', storage_options=None)

# %%
export_path=r"\\szh.loc\ssz\applikationen\OGD\Daten\Quelldaten\SSZ\Politik\abstimmungen\abstimmungen_seit1933.csv"

imp_abstimmungsresultate.to_csv(
    export_path,
    encoding="UTF-8-sig",
    quotechar='"',
    quoting=2,
    index=False,
    date_format='%Y-%m-%d'
)
print('done')

# encoding="UTF-8",
#date_format='%Y-%m-%dT%H:%M:%SZ'
# Out:
# done

# %% [markdown]
# ## Testing
#
# Teste den import der eben exportierten Daten. Klappt alles wie gewollt?

# %%
# Read the data
checkNewCsv = pd.read_csv(
    export_path, 
    parse_dates=True,
    )

# %%
checkNewCsv.info(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9850 entries, 0 to 9849
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Abstimmungs_Datum      9850 non-null   object
#  1   Nr_Politische_Ebene    9850 non-null   int64
#  2   Name_Politische_Ebene  9850 non-null   object
#  3   Abstimmungs_Text       9850 non-null   object
#  4   Nr_Resultat_Gebiet     9850 non-null   int64
#  5   Name_Resultat_Gebiet   9850 non-null   object
#  6   Nr_Wahlkreis_StZH      5255 non-null   float64
#  7   Name_Wahlkreis_StZH    5255 non-null   object
#  8   Stimmberechtigt        6710 non-null   float64
#  9   Ja                     9850 non-null   int64
#  10  Nein                   9850 non-null   int64
#  11  Stimmbeteiligung (%)   9850 non-null   float64
#  12  Ja (%)                 9850 non-null   float64
#  13  Nein (%)               9850 non-null   float64
#  14  StaendeJa              388 non-null    object
#  15  StaendeNein            392 non-null    object
# dtypes: float64(5), int64(4), object(7)
# memory usage: 1.2+ MB

# %%
from pivottablejs import pivot_ui

pivot_ui(checkNewCsv)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
checkNewCsv.query("Abstimmungs_Datum == '2022-02-13' & Nr_Politische_Ebene == 1")
# Out:
#    Abstimmungs_Datum  Nr_Politische_Ebene Name_Politische_Ebene  \
# 0         2022-02-13                    1     Eidgenossenschaft
# 1         2022-02-13                    1     Eidgenossenschaft
# 2         2022-02-13                    1     Eidgenossenschaft
# 3         2022-02-13                    1     Eidgenossenschaft
# 4         2022-02-13                    1     Eidgenossenschaft
# 5         2022-02-13                    1     Eidgenossenschaft
# 6         2022-02-13                    1     Eidgenossenschaft
# 7         2022-02-13                    1     Eidgenossenschaft
# 8         2022-02-13                    1     Eidgenossenschaft
# 9         2022-02-13                    1     Eidgenossenschaft
# 10        2022-02-13                    1     Eidgenossenschaft
# 11        2022-02-13                    1     Eidgenossenschaft
# 12        2022-02-13                    1     Eidgenossenschaft
# 13        2022-02-13                    1     Eidgenossenschaft
# 14        2022-02-13                    1     Eidgenossenschaft
# 15        2022-02-13                    1     Eidgenossenschaft
# 16        2022-02-13                    1     Eidgenossenschaft
# 17        2022-02-13                    1     Eidgenossenschaft
# 18        2022-02-13                    1     Eidgenossenschaft
# 19        2022-02-13                    1     Eidgenossenschaft
# 20        2022-02-13                    1     Eidgenossenschaft
# 21        2022-02-13                    1     Eidgenossenschaft
# 22        2022-02-13                    1     Eidgenossenschaft
# 23        2022-02-13                    1     Eidgenossenschaft
# 24        2022-02-13                    1     Eidgenossenschaft
# 25        2022-02-13                    1     Eidgenossenschaft
# 26        2022-02-13                    1     Eidgenossenschaft
# 27        2022-02-13                    1     Eidgenossenschaft
# 28        2022-02-13                    1     Eidgenossenschaft
# 29        2022-02-13                    1     Eidgenossenschaft
# 30        2022-02-13                    1     Eidgenossenschaft
# 31        2022-02-13                    1     Eidgenossenschaft
# 32        2022-02-13                    1     Eidgenossenschaft
# 33        2022-02-13                    1     Eidgenossenschaft
# 34        2022-02-13                    1     Eidgenossenschaft
# 35        2022-02-13                    1     Eidgenossenschaft
# 36        2022-02-13                    1     Eidgenossenschaft
# 37        2022-02-13                    1     Eidgenossenschaft
# 38        2022-02-13                    1     Eidgenossenschaft
# 39        2022-02-13                    1     Eidgenossenschaft
# 40        2022-02-13                    1     Eidgenossenschaft
# 41        2022-02-13                    1     Eidgenossenschaft
# 42        2022-02-13                    1     Eidgenossenschaft
# 43        2022-02-13                    1     Eidgenossenschaft
# 44        2022-02-13                    1     Eidgenossenschaft
# 45        2022-02-13                    1     Eidgenossenschaft
# 46        2022-02-13                    1     Eidgenossenschaft
# 47        2022-02-13                    1     Eidgenossenschaft
# 48        2022-02-13                    1     Eidgenossenschaft
# 49        2022-02-13                    1     Eidgenossenschaft
# 50        2022-02-13                    1     Eidgenossenschaft
# 51        2022-02-13                    1     Eidgenossenschaft
#
#                                      Abstimmungs_Text  Nr_Resultat_Gebiet  \
# 0   Volksinitiative «Ja zum Tier- und Menschenvers...                   1
# 1   Volksinitiative «Ja zum Tier- und Menschenvers...                   2
# 2   Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 3   Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 4   Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 5   Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 6   Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 7   Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 8   Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 9   Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 10  Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 11  Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 12  Volksinitiative «Ja zum Tier- und Menschenvers...                   3
# 13  Volksinitiative «Ja zum Schutz der Kinder und ...                   1
# 14  Volksinitiative «Ja zum Schutz der Kinder und ...                   2
# 15  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 16  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 17  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 18  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 19  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 20  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 21  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 22  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 23  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 24  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 25  Volksinitiative «Ja zum Schutz der Kinder und ...                   3
# 26  Änderung des Bundesgesetzes über die Stempelab...                   1
# 27  Änderung des Bundesgesetzes über die Stempelab...                   2
# 28  Änderung des Bundesgesetzes über die Stempelab...                   3
# 29  Änderung des Bundesgesetzes über die Stempelab...                   3
# 30  Änderung des Bundesgesetzes über die Stempelab...                   3
# 31  Änderung des Bundesgesetzes über die Stempelab...                   3
# 32  Änderung des Bundesgesetzes über die Stempelab...                   3
# 33  Änderung des Bundesgesetzes über die Stempelab...                   3
# 34  Änderung des Bundesgesetzes über die Stempelab...                   3
# 35  Änderung des Bundesgesetzes über die Stempelab...                   3
# 36  Änderung des Bundesgesetzes über die Stempelab...                   3
# 37  Änderung des Bundesgesetzes über die Stempelab...                   3
# 38  Änderung des Bundesgesetzes über die Stempelab...                   3
# 39  Bundesgesetz über ein Massnahmenpaket zugunste...                   1
# 40  Bundesgesetz über ein Massnahmenpaket zugunste...                   2
# 41  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
# 42  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
# 43  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
# 44  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
# 45  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
# 46  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
# 47  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
# 48  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
# 49  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
# 50  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
# 51  Bundesgesetz über ein Massnahmenpaket zugunste...                   3
#
#    Name_Resultat_Gebiet  Nr_Wahlkreis_StZH      Name_Wahlkreis_StZH  \
# 0     Eidgenossenschaft                NaN                      NaN
# 1         Kanton Zürich                NaN                      NaN
# 2          Stadt Zürich                NaN                      NaN
# 3          Stadt Zürich                2.0                Kreis 1+2
# 4          Stadt Zürich                3.0                  Kreis 3
# 5          Stadt Zürich                4.0                Kreis 4+5
# 6          Stadt Zürich                5.0                  Kreis 6
# 7          Stadt Zürich                6.0                Kreis 7+8
# 8          Stadt Zürich                7.0                  Kreis 9
# 9          Stadt Zürich                8.0                 Kreis 10
# 10         Stadt Zürich                9.0                 Kreis 11
# 11         Stadt Zürich               10.0                 Kreis 12
# 12         Stadt Zürich               17.0  Auslandschweizer/-innen
# 13    Eidgenossenschaft                NaN                      NaN
# 14        Kanton Zürich                NaN                      NaN
# 15         Stadt Zürich                NaN                      NaN
# 16         Stadt Zürich                2.0                Kreis 1+2
# 17         Stadt Zürich                3.0                  Kreis 3
# 18         Stadt Zürich                4.0                Kreis 4+5
# 19         Stadt Zürich                5.0                  Kreis 6
# 20         Stadt Zürich                6.0                Kreis 7+8
# 21         Stadt Zürich                7.0                  Kreis 9
# 22         Stadt Zürich                8.0                 Kreis 10
# 23         Stadt Zürich                9.0                 Kreis 11
# 24         Stadt Zürich               10.0                 Kreis 12
# 25         Stadt Zürich               17.0  Auslandschweizer/-innen
# 26    Eidgenossenschaft                NaN                      NaN
# 27        Kanton Zürich                NaN                      NaN
# 28         Stadt Zürich                NaN                      NaN
# 29         Stadt Zürich                2.0                Kreis 1+2
# 30         Stadt Zürich                3.0                  Kreis 3
# 31         Stadt Zürich                4.0                Kreis 4+5
# 32         Stadt Zürich                5.0                  Kreis 6
# 33         Stadt Zürich                6.0                Kreis 7+8
# 34         Stadt Zürich                7.0                  Kreis 9
# 35         Stadt Zürich                8.0                 Kreis 10
# 36         Stadt Zürich                9.0                 Kreis 11
# 37         Stadt Zürich               10.0                 Kreis 12
# 38         Stadt Zürich               17.0  Auslandschweizer/-innen
# 39    Eidgenossenschaft                NaN                      NaN
# 40        Kanton Zürich                NaN                      NaN
# 41         Stadt Zürich                NaN                      NaN
# 42         Stadt Zürich                2.0                Kreis 1+2
# 43         Stadt Zürich                3.0                  Kreis 3
# 44         Stadt Zürich                4.0                Kreis 4+5
# 45         Stadt Zürich                5.0                  Kreis 6
# 46         Stadt Zürich                6.0                Kreis 7+8
# 47         Stadt Zürich                7.0                  Kreis 9
# 48         Stadt Zürich                8.0                 Kreis 10
# 49         Stadt Zürich                9.0                 Kreis 11
# 50         Stadt Zürich               10.0                 Kreis 12
# 51         Stadt Zürich               17.0  Auslandschweizer/-innen
#
#     Stimmberechtigt       Ja     Nein  Stimmbeteiligung (%)  Ja (%)  Nein (%)  \
# 0               NaN   500937  1893539                  44.2    20.9      79.1
# 1          958009.0    90988   356755                  47.9    20.3      79.7
# 2          266675.0    25704    98575                  47.9    20.7      79.3
# 3           22746.0     2446     9537                  54.2    20.4      79.6
# 4           27831.0     2969    11343                  53.1    20.7      79.3
# 5           24460.0     2400     9433                  49.9    20.3      79.7
# 6           19564.0     2125     9196                  59.6    18.8      81.2
# 7           31328.0     3630    14909                  60.8    19.6      80.4
# 8           30971.0     3041    11118                  47.1    21.5      78.5
# 9           24233.0     2714    10843                  57.6    20.0      80.0
# 10          36995.0     3288    12699                  44.2    20.6      79.4
# 11          15731.0     1350     4317                  37.0    23.8      76.2
# 12          32816.0     1741     5180                  21.7    25.2      74.8
# 13              NaN  1370137  1049988                  44.2    56.6      43.4
# 14         459630.0   271310   181782                  48.0    59.9      40.1
# 15         266675.0    86632    39533                  48.1    68.7      31.3
# 16          22746.0     8102     4041                  54.3    66.7      33.3
# 17          27831.0    10319     4291                  53.3    70.6      29.4
# 18          24460.0     8987     3058                  50.1    74.6      25.4
# 19          19564.0     8267     3249                  59.9    71.8      28.2
# 20          31328.0    12325     6450                  61.0    65.6      34.4
# 21          30971.0     9586     4791                  47.3    66.7      33.3
# 22          24233.0     9676     4129                  57.8    70.1      29.9
# 23          36995.0    10796     5376                  44.3    66.8      33.2
# 24          15731.0     3806     1932                  37.1    66.3      33.7
# 25          32816.0     4768     2216                  21.7    68.3      31.7
# 26              NaN   882335  1481112                  44.0    37.3      62.7
# 27         958009.0   164768   279373                  47.6    37.1      62.9
# 28         266675.0    40193    83706                  47.8    32.4      67.6
# 29          22746.0     4230     7644                  53.8    35.6      64.4
# 30          27831.0     3978    10372                  53.0    27.7      72.3
# 31          24460.0     3087     8816                  49.8    25.9      74.1
# 32          19564.0     3601     7657                  59.5    32.0      68.0
# 33          31328.0     7675    10765                  60.6    41.6      58.4
# 34          30971.0     4204     9921                  47.0    29.8      70.2
# 35          24233.0     3966     9585                  57.3    29.3      70.7
# 36          36995.0     4959    10937                  44.0    31.2      68.8
# 37          15731.0     1555     4075                  36.8    27.6      72.4
# 38          32816.0     2938     3934                  21.6    42.8      57.2
# 39              NaN  1085237  1303243                  44.1    45.4      54.6
# 40         958009.0   202979   245079                  47.8    45.3      54.7
# 41         266675.0    73622    51174                  47.9    59.0      41.0
# 42          22746.0     6713     5266                  54.0    56.0      44.0
# 43          27831.0     9059     5422                  53.2    62.6      37.4
# 44          24460.0     8316     3656                  50.0    69.5      30.5
# 45          19564.0     7224     4155                  59.7    63.5      36.5
# 46          31328.0    10263     8340                  60.8    55.2      44.8
# 47          30971.0     7908     6318                  47.2    55.6      44.4
# 48          24233.0     8444     5183                  57.6    62.0      38.0
# 49          36995.0     8505     7448                  44.1    53.3      46.7
# 50          15731.0     2868     2799                  36.9    50.6      49.4
# 51          32816.0     4322     2587                  21.6    62.6      37.4
#
#    StaendeJa StaendeNein
# 0      0 0/2      20 6/2
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN
# 5        NaN         NaN
# 6        NaN         NaN
# 7        NaN         NaN
# 8        NaN         NaN
# 9        NaN         NaN
# 10       NaN         NaN
# 11       NaN         NaN
# 12       NaN         NaN
# 13    14 2/2       6 4/2
# 14       NaN         NaN
# 15       NaN         NaN
# 16       NaN         NaN
# 17       NaN         NaN
# 18       NaN         NaN
# 19       NaN         NaN
# 20       NaN         NaN
# 21       NaN         NaN
# 22       NaN         NaN
# 23       NaN         NaN
# 24       NaN         NaN
# 25       NaN         NaN
# 26     1 0/2      19 6/2
# 27       NaN         NaN
# 28       NaN         NaN
# 29       NaN         NaN
# 30       NaN         NaN
# 31       NaN         NaN
# 32       NaN         NaN
# 33       NaN         NaN
# 34       NaN         NaN
# 35       NaN         NaN
# 36       NaN         NaN
# 37       NaN         NaN
# 38       NaN         NaN
# 39     6 1/2      14 5/2
# 40       NaN         NaN
# 41       NaN         NaN
# 42       NaN         NaN
# 43       NaN         NaN
# 44       NaN         NaN
# 45       NaN         NaN
# 46       NaN         NaN
# 47       NaN         NaN
# 48       NaN         NaN
# 49       NaN         NaN
# 50       NaN         NaN
# 51       NaN         NaN
