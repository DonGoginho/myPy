# %% [markdown]
# Mit Colab kann **dieses Jupyter-Notebook interaktiv im Browser** gestartet werden:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DonGoginho/myPy/blob/main/parlamentsdienste_ris_api/pd_ris_api_al_geschaefte.ipynb)
#
# Und hier ein Jupyter-Notebook zur [generellen Verwendung der RIS-API](https://colab.research.google.com/github/opendatazurich/opendatazurich.github.io/blob/master/ris-api/RIS-API-Beispiele.ipynb)
# # Python-Abfrage an RIS-API nach Geschäftern, die von der Alternativen Liste eingegeben wurden
#
# Das Datenmodell der [**RIS-API ist als Swagger File**](https://opendatazurich.github.io/ris-api/docs/) verfügbar. Für das Verständnis ist dieses daher wichtig.
#
# **Inhaltsverzeichnis:**
#
# 1. [Mitglieder der Alternativen Liste](#Mitglieder-der-AL)
# 1. [Gemeinderats-Geschäfte](#Gemeinderats-Geschäfte)

# %%
# %pip install requests pandas
# Out:
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\gogo_gis\lib\site-packages (2.27.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\envs\gogo_gis\lib\site-packages (1.3.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\gogo_gis\lib\site-packages (from requests) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\gogo_gis\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\envs\gogo_gis\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\gogo_gis\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\envs\gogo_gis\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\envs\gogo_gis\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\envs\gogo_gis\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\gogo_gis\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from pprint import pprint
import pandas as pd
import random

# %%
SSL_VERIFY = False
# evtl. SSL_VERIFY auf False setzen wenn die Verbindung zu https://www.gemeinderat-zuerich.ch nicht klappt (z.B. wegen Proxy)
# Um die SSL Verifikation auszustellen, bitte die nächste Zeile einkommentieren ("#" entfernen)
# SSL_VERIFY = False

# %%
if not SSL_VERIFY:
    import urllib3
    urllib3.disable_warnings()

# %% [markdown]
# ## Infos zu GLP
# - 'parteiId': '0a8eb90f-6d09-47ac-99fe-ab97a77d4954'
# - 'fraktionsId': '8a269148-2a01-45f9-9e1d-c2b11d07cd31'

# %% [markdown]
# ## Mitglieder der GLP
#
# Um alle Mitglieder einer Partei zu bekommen, müssen folgende Abfragen gemacht werden:
#
#     1. ID der Partei holen
#     1. Suche nach Mitgliedern der Partei (mit dieser ID)
#     1. *Optional:* Detail-Informationen eines Mitglieds holen

# %% [markdown]
# ### Alle relevanten Mitglieder-Parameter holen
#
# Lese alle Parameter zu den Mitgliedern in `params` ein

# %%
headers = {'Accept': 'application/json'}
r = requests.get('https://www.gemeinderat-zuerich.ch/api/Mitglieder/parameter', headers=headers, verify=SSL_VERIFY)
params = r.json()
#params

# %% [markdown]
# Lese die Informationen zu den Parteien aus `params`heraus

# %%
# get id of AL
parties = params['Parteien']
#party = {'parteiId': 'df5ccd54-009e-40ae-b687-4ce88a71f5d8'}
parties
# Out:
# [{'Name': 'AL', 'Id': 'df5ccd54-009e-40ae-b687-4ce88a71f5d8'},
#  {'Name': 'CVP', 'Id': '5964b653-a32a-4e0c-92a1-07720566a92c'},
#  {'Name': 'EVP', 'Id': '187b7ad1-2095-43cc-b257-e9834a54a961'},
#  {'Name': 'FDP', 'Id': '8240033e-4818-4406-8f73-b7829d99ddee'},
#  {'Name': 'GLP', 'Id': '0a8eb90f-6d09-47ac-99fe-ab97a77d4954'},
#  {'Name': 'Grüne', 'Id': 'fe956d66-e14d-4739-82cf-c12202d96445'},
#  {'Name': 'Parteilos', 'Id': '9e037de7-40a4-4fa3-85b7-f4c30cbb26c8'},
#  {'Name': 'SP', 'Id': '6cb1a3bb-8e26-4818-a8f5-0ea49ab3cd57'},
#  {'Name': 'SVP', 'Id': '8e484ad9-6e46-4d39-bc05-fbf18be11b0c'}]

# %% [markdown]
# Für diese Anfrage ist die AL relevant. Definiere daher als `party`die gesuchte Partei

# %%
party = {'parteiId': '0a8eb90f-6d09-47ac-99fe-ab97a77d4954','Name': 'GLP'}
party
# Out:
# {'parteiId': '0a8eb90f-6d09-47ac-99fe-ab97a77d4954', 'Name': 'GLP'}

# %% [markdown]
# ### Mitglieder der AL abfragen

# %% [markdown]
# In der Query wird die ParteiId angegeben, welche für die Abfrage des Endpoints relevant ist.
# In `members`wird das Resultat der Abfrage als JSON-Array eingelesen.

# %%
query = {'parteiId':  '0a8eb90f-6d09-47ac-99fe-ab97a77d4954'}
#query = {'fraktionsId': '8a269148-2a01-45f9-9e1d-c2b11d07cd31'}
headers = {'Accept': 'application/json'}
r = requests.get('https://www.gemeinderat-zuerich.ch/api/Mitglieder/suchen', params=query, headers=headers, verify=SSL_VERIFY)
members = r.json()
#members

# %% [markdown]
# ### Details zu den AL-Mitgliedern abfragen
#
# Mit dem `/Mitglieder/details` Endpunkt können Details eines Mitglieds abgefragt werden. Dazu muss die Mitglieder-ID jedes Mitglieds herausgelesen und über die API abgefragt werden. Dies erfolgt über die Funktion `get_member_details()`.

# %%
#members

# %%
def get_member_details(member):
    #print(member)
    query = {'mid': member['Id']}
    #print(query)
    headers = {'Accept': 'application/json'}
    r = requests.get('https://www.gemeinderat-zuerich.ch/api/Mitglieder/details', params=query, headers=headers, verify=SSL_VERIFY)
    details = r.json()
    
    # trim "Wahlkreis" and "Wohnkreis" since they have a padding
    details['Wahlkreis'] = details['Wahlkreis'].strip()
    if details['Wohnkreis']:
        details['Wohnkreis'] = details['Wohnkreis'].strip()
    # add original member to keep WahlkreisOrderBy column
    details.update(member)
    return details
    
member_details = [get_member_details(m) for m in members]
df = pd.DataFrame(member_details)
df
# Out:
#                                       Id        Name        Vorname Anrede  \
# 0   32e89ef8-f5b2-46e5-aafe-7dd15929f00a     Baumann         Markus   Herr
# 1   e19095bc-beed-43e2-9e39-685c46f8d577     Cavalli        Nicolas   Herr
# 2   6a6e0c52-3ae0-48d3-b7d3-a9412dad103b      Garcia         Isabel   Frau
# 3   a0692db6-12d8-462b-a02d-b3b3f3045551  Hofer Frei         Simone   Frau
# 4   aa77152d-5fde-4725-8c69-21c022000ec8  Krayenbühl            Guy   Herr
# 5   6f80de0e-2322-46c4-891b-3a2781b127c9     Landolt        Maleica   Frau
# 6   09fccfe6-c6e3-487e-8efc-4db1e8af3d8f       Merki         Markus   Herr
# 7   f5ae2bc7-e3c4-4f2e-96b8-0b4c1abbb87d        Monn      Christian   Herr
# 8   162e20b7-31de-46ef-b520-0021c3e269cb     Nabholz  Ann-Catherine   Frau
# 9   1a2aa558-cbd2-4ab6-8725-7c791cec92ad       Novak        Martina   Frau
# 10  2a3c2952-2d61-47a8-9d89-50890a81ba27  Oberholzer           Beat   Herr
# 11  0e7fb39a-8768-47e2-88c9-1351d20d80d1         Roy        Shaibal   Herr
# 12  058af0e5-dd56-4d66-a90b-4b9994b553fe        Siev          Ronny   Herr
# 13  e77ac228-d6c5-42ee-9862-6a2cfeb1605f  Sobernheim           Sven   Herr
#
#    Titel           Geburtstag Wohnkreis  \
# 0   None  1973-09-19T00:00:00      None
# 1   None  1982-11-09T00:00:00         4
# 2   None  1963-06-15T00:00:00         3
# 3   None  1974-12-16T00:00:00         6
# 4         1968-01-29T00:00:00         3
# 5   None  1967-06-05T00:00:00        11
# 6   None  1977-10-04T00:00:00        11
# 7   Dr.   1959-12-13T00:00:00        11
# 8    Dr.  1968-04-18T00:00:00         7
# 9   None  1985-01-16T00:00:00         8
# 10  None  1978-11-13T00:00:00         3
# 11  None  1977-03-24T00:00:00        10
# 12  None  1974-01-09T00:00:00         6
# 13  None  1989-09-22T00:00:00        11
#
#                                         Beruf Partei Fraktion  ...  \
# 0   Fachmann für Arbeitsintegration/Job Coach    GLP      GLP  ...
# 1                                  Consultant    GLP      GLP  ...
# 2       Politologin & Kommunikationsberaterin    GLP      GLP  ...
# 3      Redaktorin / Ökonomin (lic. rer. pol.)    GLP      GLP  ...
# 4                                Staatsanwalt    GLP      GLP  ...
# 5                           Pflegefachfrau HF    GLP      GLP  ...
# 6            Bau- und Wirtschaftsingenieur FH    GLP      GLP  ...
# 7     wissenschaftlicher Mitarbeiter / Dozent    GLP      GLP  ...
# 8                                    Dozentin    GLP      GLP  ...
# 9                            Leiterin Politik    GLP      GLP  ...
# 10                    Wirtschaftsinformatiker    GLP      GLP  ...
# 11                             Betriebsökonom    GLP      GLP  ...
# 12        lic. phil. I, Politikwissenschafter    GLP      GLP  ...
# 13                         Verkehrsplaner ZFH    GLP      GLP  ...
#
#                               EmailPrivat        EmailGeschaeftlich  \
# 0               baumann-markus@bluewin.ch
# 1         nicolas.cavalli@grunliberale.ch                      None
# 2               garciaisabel_@hotmail.com
# 3                simone.hofer@econtext.ch  simone.hofer@econtext.ch
# 4                  mail@guykrayenbuehl.ch
# 5              maleika.landolt@vtxmail.ch                      None
# 6                markus.merki@hotmail.com
# 7                        cmonn@hispeed.ch
# 8   ann-catherine.nabholz@grunliberale.ch                      None
# 9          martinanovak.politik@gmail.com
# 10                     beat@oberholzer.li                      None
# 11            shaibal.roy@grunliberale.ch                      None
# 12                   ronny.siev@gmail.com
# 13                   sven.sobes@gmail.com                      None
#
#      Mobiltelefon MobiltelefonGeschaeftlich TelefonGeschaeftlich  \
# 0   076 396 19 20                      None                 None
# 1   078 602 27 70                      None                 None
# 2   079 652 85 19                      None
# 3   078 612 08 21             078 612 08 21                 None
# 4   076 386 86 16                                  044 248 21 11
# 5   079 317 33 71                      None        044 811 07 77
# 6                                      None
# 7                                      None
# 8   079 561 49 82                      None                 None
# 9                                      None
# 10  076 369 04 05                      None                 None
# 11  076 336 19 77                      None                 None
# 12  079 299 20 27                      None
# 13                                     None                 None
#
#     TelefonPrivat             Internetauftritt  \
# 0            None
# 1            None                         None
# 2
# 3                              www.econtext.ch
# 4            None                         None
# 5   043 300 12 60                         None
# 6            None                         None
# 7                         www.christianmonn.ch
# 8   043 488 69 85                         None
# 9            None                         None
# 10           None  https://beat-oberholzer.ch/
# 11  044 240 40 36                         None
# 12           None                         None
# 13           None                sobernheim.ch
#
#                                Interessenverbindungen  \
# 0                                                None
# 1                                                None
# 2   - Secondas Zürich, Präsidentin\r- Mitglied des...
# 3   - LAC TV Unterstrass, Zürich, Trainerin\r- Vét...
# 4                                                None
# 5   - Rotkreuzdienst Schweiz, Bern, OGfr. RKD+\r- ...
# 6   - Grünliberale Kreis 11 & 12, Vorstandsmitglie...
# 7                                                None
# 8      - Theater Neumarkt AG, Mitglied Verwaltungsrat
# 9                                                None
# 10  - Heimgenossenschaft Schweighof, Zürich, Mitgl...
# 11         - Second@s Plus, Zürich, Vorstandsmitglied
# 12                                               None
# 13  - Vorstandsmitglied Pro Nachtleben Zürich\r- V...
#
#                   NameInUrl WahlkreisOrderBy
# 0          Markus%20Baumann              105
# 1         Nicolas%20Cavalli              102
# 2           Isabel%20Garcia              101
# 3     Simone%20Hofer%20Frei              103
# 4     Guy%20Krayenb%c3%bchl              100
# 5         Maleica%20Landolt              107
# 6            Markus%20Merki              107
# 7          Christian%20Monn              108
# 8   Ann-Catherine%20Nabholz              104
# 9           Martina%20Novak              104
# 10        Beat%20Oberholzer              101
# 11            Shaibal%20Roy              102
# 12             Ronny%20Siev              106
# 13        Sven%20Sobernheim              107
#
# [14 rows x 24 columns]

# %%
# Beispiel einer Grafik dazu
#count_by_wahlkreis = df[['Wahlkreis', 'WahlkreisOrderBy']].groupby(['Wahlkreis', 'WahlkreisOrderBy']).size().reset_index(name='Anzahl')
#count_by_wahlkreis = count_by_wahlkreis.sort_values(by=['WahlkreisOrderBy'])
#count_by_wahlkreis.plot.bar(x='Wahlkreis', y='Anzahl')

# %% [markdown]
# # Anfrage der Parlamentsdienste
#
# Das Interesse gilt allen durch ein GLP-Ratsmitglied oder die GLP-Fraktion eingereichten Vorstösse in dieser Legislatur.
#
# Es müsste im Datensatz in etwa folgender Filter gesetzt werden:
# - Geschäftsart=Motion, Postulat, Interpellation, Schriftliche Anfrage, Beschlussantrag oder Globalbudgetantrag
# - Akteure/Einreichende Person=GLP (muss der Partei "GLP" angehören)
# - Zeitraum=16.05.2018 bis 03.05.2022
#
# IDs zur GLP
# - 'parteiId':  '0a8eb90f-6d09-47ac-99fe-ab97a77d4954'
# - 'fraktionsId': '8a269148-2a01-45f9-9e1d-c2b11d07cd31'
#
# Resultat:
# Liste mit Angaben zu
# - Geschäftsnummer
# - Geschäftstitel
# - Geschäftsart
# - Einreichende Person/Partei/Fraktion: GLP
# - Link auf das Geschäft auf der Website des Gemeinderats

# %% [markdown]
# ## Gemeinderats-Geschäfte die von der GLP eingereicht wurden
#
# Im der Resultatsliste sollen alls Geschäfte aufgelistet werden, welche die GLP entweder als Partei oder als Fraktion eingegeben hat.
#
# 1.   Stelle zuerst den Request auf die Geschäfte, welche von der GLP **als Fraktion** eingegeben wurden und übergebe das Resultat aus einem JSON (`result_geschaefte_fraktion`) in einen Dataframe (`df_deals_fraktion`).

# %%
#query = {'personId': member['Id']}

# via swagger: URL mit einem OR Operatoren drin
#https://www.gemeinderat-zuerich.ch/api/Geschaeft/suchen?parteiId=df5ccd54-009e-40ae-b687-4ce88a71f5d8|fraktionId=53bf7290-4055-455b-bb1f-2ba64e76294d&orderBy=geschaeftsart

query_fraktion = {'fraktionId': '8a269148-2a01-45f9-9e1d-c2b11d07cd31', 'activePage':1, 'pageSize':700}
headers = {'Accept': 'application/json'}
r = requests.get('https://www.gemeinderat-zuerich.ch/api/Geschaeft', 
                 params=query_fraktion, 
                 headers=headers, 
                 verify=SSL_VERIFY)
result_geschaefte_fraktion = r.json()
df_deals_fraktion = pd.DataFrame(result_geschaefte_fraktion['Geschaefte'])
print('done')
# Out:
# done

# %%
df_deals_fraktion.info
# Out:
# <bound method DataFrame.info of                               GeschaeftId  Geschaeftsjahr  Geschaeftsnummer  \
# 0    b21dde90-7652-44e6-bc1f-abf23b760d12            2022               103
# 1    25e80ba4-9deb-4f85-8d0a-f35fa1160498            2022                92
# 2    5c2bf33e-5ff8-48f7-a7b2-1b3b783dc0d0            2022                88
# 3    e31012f6-347b-48cd-a7cb-fbfbca017713            2022                76
# 4    41dedcfb-0e34-4456-bddd-47eb70a78dbd            2022                69
# ..                                    ...             ...               ...
# 235  0502e52c-9ce0-466f-9503-826c6cdb3799            2010               518
# 236  15ef01f9-7967-459c-8063-a18785272bb2            2010               421
# 237  168944e8-5535-4bfa-894d-537f7cca085c            2010               323
# 238  7c62d067-f93a-4764-9623-4cda8fa09f19            2010               307
# 239  06bfef68-7dbe-46c6-a84a-c0de5bfccf57            2010               239
#
#                                        Geschaeftstitel    Geschaeftsart
# 0             Rückkehr des Gemeinderats in das Rathaus  Beschlussantrag
# 1    Impact Hub Zürich, Zusammenarbeit, Projekte un...   Interpellation
# 2    Einheitliche Regelung betreffend Nutzung des ö...         Postulat
# 3    Definitive Einführung der Tagesschule nach dem...        Erklärung
# 4    Schauspielhaus, Quartier Hottingen, Modernisie...        Erklärung
# ..                                                 ...              ...
# 235                          Voranschlag (Budget) 2011        Erklärung
# 236  Grüngutabfuhr für die Biogasanlage Werdhölzli,...           Motion
# 237  Quartieranbindung Ost Bahnhof Oerlikon, Aufwei...         Postulat
# 238  Volksinitiativen "Sofort-Massnahmen Zürich Nor...        Erklärung
# 239  Teilrevision der städtischen Parkplatzverordnu...        Erklärung
#
# [240 rows x 5 columns]>

# %% [markdown]
# 2.   Stelle anschliessend den Request auf die Geschäfte, welche von der GLP **als Partei** eingegeben wurden und übergebe das Resultat aus einem JSON (result_geschaefte_partei) in einen Dataframe (df_deals_partei).

# %%
query_partei = {'parteiId': '0a8eb90f-6d09-47ac-99fe-ab97a77d4954', 'activePage':1, 'pageSize':700}
headers = {'Accept': 'application/json'}
r = requests.get('https://www.gemeinderat-zuerich.ch/api/Geschaeft', 
                 params=query_partei, 
                 headers=headers, 
                 verify=SSL_VERIFY)
result_geschaefte_partei = r.json()
df_deals_partei = pd.DataFrame(result_geschaefte_partei['Geschaefte'])
print('done')
# Out:
# done

# %%
df_deals_partei.info
# Out:
# <bound method DataFrame.info of                               GeschaeftId  Geschaeftsjahr  Geschaeftsnummer  \
# 0    61720d59-0a1a-45b5-820a-2f0f988f0fdf            2022               133
# 1    72a578b2-d377-4b35-9cbf-e72ce850317f            2022               108
# 2    bc475206-69c9-4b10-9ebb-55ecddb1c75f            2022               107
# 3    5b38e1d4-8c90-4502-8e2c-a383e314c6cd            2022               106
# 4    54de7aef-848d-4f75-b2d1-0618bdcb5365            2022                93
# ..                                    ...             ...               ...
# 331  f1e133b0-9364-43b4-8aac-05108476ed32            2005               291
# 332  f174da4d-ee17-49d1-9732-3aa9b47e6050            2005               210
# 333  ddb76021-d2da-4d09-8907-faff44891e0f            2004               611
# 334  9b3b28bd-bb24-46f3-bb15-4329aa1d2207            2004               533
# 335  b2e323e3-5ed8-4a12-a4c4-5a6ad91a01d6            2004               150
#
#                                        Geschaeftstitel         Geschaeftsart
# 0    Fehlende Krankentaggeldversicherung, Gründe fü...  Schriftliche Anfrage
# 1    Zeitlich begrenzte berufliche und schulische A...              Postulat
# 2    Einrichtung einer zeitlich begrenzten Anlaufst...              Postulat
# 3    Errichtung einer Jobplattform für Personen mit...              Postulat
# 4    Gratisplakatierung vor den Wahlen, Kriterien f...        Interpellation
# ..                                                 ...                   ...
# 331  Geschäftsberichte, Bezugnahme auf Rechnungsabs...              Postulat
# 332  Seebad Utoquai, vorzeitige Schliessung am 15.8...  Schriftliche Anfrage
# 333  Villa Mooser, Mietkonditionen für den künftige...        Interpellation
# 334  Bewilligungsverfahren von Amtsstellen, Vereinf...              Postulat
# 335  Unterricht in Biblischer Geschichte, finanziel...              Postulat
#
# [336 rows x 5 columns]>

# %% [markdown]
# Füge nun beide DataFrames der Teilanfragen (1 und 2) zusammen.
# `ignore_index` ist hier wichtig, sonst funktioniert das zusammenhängen nicht wie erwünscht.
# Sortiere danach den DataFrame absteigend nach Geschäftsjahr und Geschäftsnummer und schreibe ihn in den DataFrame df_deals.

# %%
#df_deals_partei.columns
df_deals_partei.dtypes
#df_deals_fraktion.dtypes
# Out:
# GeschaeftId         object
# Geschaeftsjahr       int64
# Geschaeftsnummer     int64
# Geschaeftstitel     object
# Geschaeftsart       object
# dtype: object

# %%
df_deals_appended = df_deals_partei.append(df_deals_fraktion, verify_integrity=True, ignore_index=True, sort=True)
df_deals = df_deals_appended.sort_values(by=['Geschaeftsjahr', 'Geschaeftsnummer'], ascending=False)
df_deals
#result = df1.append(df4, sort=False)
# Out:
#                               GeschaeftId         Geschaeftsart  \
# 0    61720d59-0a1a-45b5-820a-2f0f988f0fdf  Schriftliche Anfrage
# 1    72a578b2-d377-4b35-9cbf-e72ce850317f              Postulat
# 2    bc475206-69c9-4b10-9ebb-55ecddb1c75f              Postulat
# 3    5b38e1d4-8c90-4502-8e2c-a383e314c6cd              Postulat
# 336  b21dde90-7652-44e6-bc1f-abf23b760d12       Beschlussantrag
# ..                                    ...                   ...
# 331  f1e133b0-9364-43b4-8aac-05108476ed32              Postulat
# 332  f174da4d-ee17-49d1-9732-3aa9b47e6050  Schriftliche Anfrage
# 333  ddb76021-d2da-4d09-8907-faff44891e0f        Interpellation
# 334  9b3b28bd-bb24-46f3-bb15-4329aa1d2207              Postulat
# 335  b2e323e3-5ed8-4a12-a4c4-5a6ad91a01d6              Postulat
#
#      Geschaeftsjahr  Geschaeftsnummer  \
# 0              2022               133
# 1              2022               108
# 2              2022               107
# 3              2022               106
# 336            2022               103
# ..              ...               ...
# 331            2005               291
# 332            2005               210
# 333            2004               611
# 334            2004               533
# 335            2004               150
#
#                                        Geschaeftstitel
# 0    Fehlende Krankentaggeldversicherung, Gründe fü...
# 1    Zeitlich begrenzte berufliche und schulische A...
# 2    Einrichtung einer zeitlich begrenzten Anlaufst...
# 3    Errichtung einer Jobplattform für Personen mit...
# 336           Rückkehr des Gemeinderats in das Rathaus
# ..                                                 ...
# 331  Geschäftsberichte, Bezugnahme auf Rechnungsabs...
# 332  Seebad Utoquai, vorzeitige Schliessung am 15.8...
# 333  Villa Mooser, Mietkonditionen für den künftige...
# 334  Bewilligungsverfahren von Amtsstellen, Vereinf...
# 335  Unterricht in Biblischer Geschichte, finanziel...
#
# [576 rows x 5 columns]

# %%
df_deals = df_deals_appended.sort_values(by=['Geschaeftsjahr', 'Geschaeftsnummer'], ascending=False)

# %% [markdown]
# Check Output des Dataframes

# %%
df_deals.head()
# Out:
#                               GeschaeftId         Geschaeftsart  \
# 0    61720d59-0a1a-45b5-820a-2f0f988f0fdf  Schriftliche Anfrage
# 1    72a578b2-d377-4b35-9cbf-e72ce850317f              Postulat
# 2    bc475206-69c9-4b10-9ebb-55ecddb1c75f              Postulat
# 3    5b38e1d4-8c90-4502-8e2c-a383e314c6cd              Postulat
# 336  b21dde90-7652-44e6-bc1f-abf23b760d12       Beschlussantrag
#
#      Geschaeftsjahr  Geschaeftsnummer  \
# 0              2022               133
# 1              2022               108
# 2              2022               107
# 3              2022               106
# 336            2022               103
#
#                                        Geschaeftstitel
# 0    Fehlende Krankentaggeldversicherung, Gründe fü...
# 1    Zeitlich begrenzte berufliche und schulische A...
# 2    Einrichtung einer zeitlich begrenzten Anlaufst...
# 3    Errichtung einer Jobplattform für Personen mit...
# 336           Rückkehr des Gemeinderats in das Rathaus

# %% [markdown]
# Exportiere die Geschäfte dieser Anfrage als Excel und als CSV.

# %%
#df_deals.to_csv('deals.csv')  
df_deals.to_excel('glp_deals.xlsx')

# %% [markdown]
# ## Details der Gemeinderats-Geschäfte abfragen
#
# Die Abfrage über den Geschäftsendpoint ('https://www.gemeinderat-zuerich.ch/api/Geschaeft') liefert keine detaillierten Daten. Z.B wer das Geschäft eingereicht hat oder wie der aktuelle Stand dabei ist.
#
# Dazu muss der Endpoint zu den Geschäftsdetails ('https://www.gemeinderat-zuerich.ch/api/Geschaeft/details') abgefragt werden. Dieser benötigt als Input die ID des Geschäfts (die gid).

# %%
def get_geschaefte_details(index):
    #Herauslesen der GeschaeftId aus dem Dataframe df_deals
    query = {'gid': df_deals['GeschaeftId'][index]}
    #print(query)
    headers = {'Accept': 'application/json'}
    r = requests.get('https://www.gemeinderat-zuerich.ch/api/Geschaeft/details', params=query, headers=headers, verify=SSL_VERIFY) 
    details = r.json()
    # Da komischerweise in den Details die gid nicht mehr vorkommt, weise ich sie hier explizit zu, damit sie im Output vorkommt.
    details['gid'] = df_deals['GeschaeftId'][index]
    return details
 
#Iterrows ist nicht die schnellste Variante der Abfrage. Aber hier dennoch zweckmässig.
deals_details = [get_geschaefte_details(index) for index, row in df_deals.iterrows()]
print("done")
# Out:
# done

# %% [markdown]
# Einlsesen des JSON-Outputs in einen DataFrame.
# Beachte die Struktur des Outputs. Siehe auch https://opendatazurich.github.io/ris-api/docs/#/Geschaeft/get_Geschaeft_details > Model

# %%
df_deals_details = pd.DataFrame(deals_details)
df_deals_details
# Out:
#                                         GeschaeftTitel  GeschaeftsJahr  \
# 0    Fehlende Krankentaggeldversicherung, Gründe fü...            2022
# 1    Zeitlich begrenzte berufliche und schulische A...            2022
# 2    Einrichtung einer zeitlich begrenzten Anlaufst...            2022
# 3    Errichtung einer Jobplattform für Personen mit...            2022
# 4             Rückkehr des Gemeinderats in das Rathaus            2022
# ..                                                 ...             ...
# 571  Geschäftsberichte, Bezugnahme auf Rechnungsabs...            2005
# 572  Seebad Utoquai, vorzeitige Schliessung am 15.8...            2005
# 573  Villa Mooser, Mietkonditionen für den künftige...            2004
# 574  Bewilligungsverfahren von Amtsstellen, Vereinf...            2004
# 575  Unterricht in Biblischer Geschichte, finanziel...            2004
#
#      GeschaeftsNummer         GeschaeftsArt  \
# 0                 133  Schriftliche Anfrage
# 1                 108              Postulat
# 2                 107              Postulat
# 3                 106              Postulat
# 4                 103       Beschlussantrag
# ..                ...                   ...
# 571               291              Postulat
# 572               210  Schriftliche Anfrage
# 573               611        Interpellation
# 574               533              Postulat
# 575               150              Postulat
#
#                                   Erstunterzeichnender  \
# 0    {'Id': 'e19095bc-beed-43e2-9e39-685c46f8d577',...
# 1    {'Id': '32e89ef8-f5b2-46e5-aafe-7dd15929f00a',...
# 2    {'Id': '32e89ef8-f5b2-46e5-aafe-7dd15929f00a',...
# 3    {'Id': 'aa77152d-5fde-4725-8c69-21c022000ec8',...
# 4                                                 None
# ..                                                 ...
# 571  {'Id': 'bf3cdcb5-e2dd-44e0-8cf3-f21d1ccb6e0e',...
# 572  {'Id': '87cf2c8f-edda-4afa-b680-a683e1601fba',...
# 573  {'Id': 'fdfcd10d-7734-47af-b898-83e478aa07b9',...
# 574  {'Id': 'fdfcd10d-7734-47af-b898-83e478aa07b9',...
# 575  {'Id': '2fe4ac1e-5d58-4546-9d26-618b3980ca74',...
#
#                            ZweiterErstunterzeichnender  \
# 0    {'Id': 'e77ac228-d6c5-42ee-9862-6a2cfeb1605f',...
# 1    {'Id': '6a6e0c52-3ae0-48d3-b7d3-a9412dad103b',...
# 2    {'Id': '6a6e0c52-3ae0-48d3-b7d3-a9412dad103b',...
# 3    {'Id': 'e77ac228-d6c5-42ee-9862-6a2cfeb1605f',...
# 4                                                 None
# ..                                                 ...
# 571  {'Id': 'fdfcd10d-7734-47af-b898-83e478aa07b9',...
# 572  {'Id': 'fdfcd10d-7734-47af-b898-83e478aa07b9',...
# 573                                               None
# 574                                               None
# 575  {'Id': 'fdfcd10d-7734-47af-b898-83e478aa07b9',...
#
#                                     EinreichendeGruppe   PendentBei  \
# 0                                                   []     Stadtrat
# 1                                                   []  Gemeinderat
# 2                                                   []  Gemeinderat
# 3                                                   []  Gemeinderat
# 4    [{'Name': 'AL', 'Id': '53bf7290-4055-455b-bb1f...
# ..                                                 ...          ...
# 571                                                 []
# 572                                                 []
# 573                                                 []
# 574                                                 []
# 575                                                 []
#
#                   FristBis                                       Departemente  \
# 0    2022-07-06T21:26:12.1        [{'Id': 1, 'Name': 'Zuteilung ausstehend'}]
# 1                     None     [{'Id': 11, 'Name': 'Sozialdepartement (SD)'}]
# 2                     None     [{'Id': 11, 'Name': 'Sozialdepartement (SD)'}]
# 3                     None     [{'Id': 11, 'Name': 'Sozialdepartement (SD)'}]
# 4      0001-01-01T00:00:00                                                 []
# ..                     ...                                                ...
# 571    0001-01-01T00:00:00      [{'Id': 4, 'Name': 'Finanzdepartement (FD)'}]
# 572    0001-01-01T00:00:00  [{'Id': 7, 'Name': 'Tiefbau- und Entsorgungsde...
# 573    0001-01-01T00:00:00      [{'Id': 4, 'Name': 'Finanzdepartement (FD)'}]
# 574    0001-01-01T00:00:00  [{'Id': 3, 'Name': 'Präsidialdepartement (PRD)'}]
# 575    0001-01-01T00:00:00  [{'Id': 10, 'Name': 'Schul- und Sportdeparteme...
#
#                                         Ablaufschritte  \
# 0    [{'Datum': '2022-04-06T00:00:00', 'Created': '...
# 1    [{'Datum': '2022-04-06T00:00:00', 'Created': '...
# 2    [{'Datum': '2022-04-06T00:00:00', 'Created': '...
# 3    [{'Datum': '2022-04-06T00:00:00', 'Created': '...
# 4    [{'Datum': '2022-04-06T00:00:00', 'Created': '...
# ..                                                 ...
# 571  [{'Datum': '2008-09-17T00:00:00', 'Created': '...
# 572  [{'Datum': '2005-10-26T00:00:00', 'Created': '...
# 573  [{'Datum': '2007-05-09T00:00:00', 'Created': '...
# 574  [{'Datum': '2007-09-19T00:00:00', 'Created': '...
# 575  [{'Datum': '2008-09-17T00:00:00', 'Created': '...
#
#                                  VerknuepfteGeschaefte  \
# 0    [{'GeschaeftId': '8d6ea382-eeb3-45a8-a7dd-8886...
# 1    [{'GeschaeftId': 'bc475206-69c9-4b10-9ebb-55ec...
# 2    [{'GeschaeftId': '72a578b2-d377-4b35-9cbf-e72c...
# 3    [{'GeschaeftId': '72a578b2-d377-4b35-9cbf-e72c...
# 4                                                   []
# ..                                                 ...
# 571                                                 []
# 572                                                 []
# 573                                                 []
# 574                                                 []
# 575                                                 []
#
#                                       gid
# 0    61720d59-0a1a-45b5-820a-2f0f988f0fdf
# 1    72a578b2-d377-4b35-9cbf-e72ce850317f
# 2    bc475206-69c9-4b10-9ebb-55ecddb1c75f
# 3    5b38e1d4-8c90-4502-8e2c-a383e314c6cd
# 4    b21dde90-7652-44e6-bc1f-abf23b760d12
# ..                                    ...
# 571  f1e133b0-9364-43b4-8aac-05108476ed32
# 572  f174da4d-ee17-49d1-9732-3aa9b47e6050
# 573  ddb76021-d2da-4d09-8907-faff44891e0f
# 574  9b3b28bd-bb24-46f3-bb15-4329aa1d2207
# 575  b2e323e3-5ed8-4a12-a4c4-5a6ad91a01d6
#
# [576 rows x 13 columns]

# %% [markdown]
# In der Anfrage ist ein Link auf das Geschäft gewünscht. Die URL hat einen fixen Teil an den am Ende die gid des Geschäfts angehängt wird.
# Da der Link nicht im Datenmodell vorhanden ist, wird er hier erstellt und dem DataFrame angehängt.

# %%
#df_deals_details['joined_col'] = df_deals_details.GeschaeftsArt.str.cat(df_deals_details.PendentBei)
basis_url_geschaefte = "https://www.gemeinderat-zuerich.ch/geschaefte/detailansicht-geschaeft?gid="

df_deals_details['deals_details_url'] = basis_url_geschaefte + df_deals_details.gid

df_deals_details.head(3)
#print(basis_url_geschaefte +''+ df_deals_details.gid)
# Out:
#                                       GeschaeftTitel  GeschaeftsJahr  \
# 0  Fehlende Krankentaggeldversicherung, Gründe fü...            2022
# 1  Zeitlich begrenzte berufliche und schulische A...            2022
# 2  Einrichtung einer zeitlich begrenzten Anlaufst...            2022
#
#    GeschaeftsNummer         GeschaeftsArt  \
# 0               133  Schriftliche Anfrage
# 1               108              Postulat
# 2               107              Postulat
#
#                                 Erstunterzeichnender  \
# 0  {'Id': 'e19095bc-beed-43e2-9e39-685c46f8d577',...
# 1  {'Id': '32e89ef8-f5b2-46e5-aafe-7dd15929f00a',...
# 2  {'Id': '32e89ef8-f5b2-46e5-aafe-7dd15929f00a',...
#
#                          ZweiterErstunterzeichnender EinreichendeGruppe  \
# 0  {'Id': 'e77ac228-d6c5-42ee-9862-6a2cfeb1605f',...                 []
# 1  {'Id': '6a6e0c52-3ae0-48d3-b7d3-a9412dad103b',...                 []
# 2  {'Id': '6a6e0c52-3ae0-48d3-b7d3-a9412dad103b',...                 []
#
#     PendentBei               FristBis  \
# 0     Stadtrat  2022-07-06T21:26:12.1
# 1  Gemeinderat                   None
# 2  Gemeinderat                   None
#
#                                      Departemente  \
# 0     [{'Id': 1, 'Name': 'Zuteilung ausstehend'}]
# 1  [{'Id': 11, 'Name': 'Sozialdepartement (SD)'}]
# 2  [{'Id': 11, 'Name': 'Sozialdepartement (SD)'}]
#
#                                       Ablaufschritte  \
# 0  [{'Datum': '2022-04-06T00:00:00', 'Created': '...
# 1  [{'Datum': '2022-04-06T00:00:00', 'Created': '...
# 2  [{'Datum': '2022-04-06T00:00:00', 'Created': '...
#
#                                VerknuepfteGeschaefte  \
# 0  [{'GeschaeftId': '8d6ea382-eeb3-45a8-a7dd-8886...
# 1  [{'GeschaeftId': 'bc475206-69c9-4b10-9ebb-55ec...
# 2  [{'GeschaeftId': '72a578b2-d377-4b35-9cbf-e72c...
#
#                                     gid  \
# 0  61720d59-0a1a-45b5-820a-2f0f988f0fdf
# 1  72a578b2-d377-4b35-9cbf-e72ce850317f
# 2  bc475206-69c9-4b10-9ebb-55ecddb1c75f
#
#                                    deals_details_url
# 0  https://www.gemeinderat-zuerich.ch/geschaefte/...
# 1  https://www.gemeinderat-zuerich.ch/geschaefte/...
# 2  https://www.gemeinderat-zuerich.ch/geschaefte/...

# %% [markdown]
# Exportiere den erstellten DataFrame.
# Z.K. im DataFrame sieht es aus als ob die URL nicht sauber Concatenated wird. Im Excel-Output ist jedoch alles i.O.

# %%
df_deals_details.to_excel('glp_deals_details.xlsx')  
#url_geschaefte = "https://www.gemeinderat-zuerich.ch/geschaefte/detailansicht-geschaeft?gId="df_deals_details['gid']

# %% [markdown]
# ### Normalisierung der Geschäftsdetails
#
# Der Output der Detailinformationen ist verschachtelt, wie im [Datenmodell](https://opendatazurich.github.io/ris-api/docs/#/Geschaeft/get_Geschaeft_details) beschrieben. In den nächsten Schritten wird der DataFrame mit den Datails zu den Geschäften normalisiert. Siehe dazu z.B folgende Links:
# - https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.io.json.json_normalize.html
# - https://towardsdatascience.com/all-pandas-json-normalize-you-should-know-for-flattening-json-13eae1dfb7dd
# - https://blog.softhints.com/python-normalize-json-pandas/

# %% [markdown]
# Hier im ersten Versuch werden keine weiteren Parameter angegeben. Es ist jedoch ersichtlich, dass dies nicht dem von uns erhofften Output entspricht. Es ist unklar, was mit den Erstunterzeichnenden geschehen ist ... jedenfalls nützt das so nichts.

# %%
from pandas.io.json import json_normalize

# %%
#df_deals_details_normalized = pd.json_normalize(deals_details, sep="_")

df_deals_details_normalized = pd.json_normalize(deals_details)
#, max_level=1


df_deals_details_normalized.columns
#df_deals_details_normalized.head(3)
#df_deals_details_normalized.to_excel(path+'deals_details_normalized.xlsx')
# Out:
# Index(['GeschaeftTitel', 'GeschaeftsJahr', 'GeschaeftsNummer', 'GeschaeftsArt',
#        'EinreichendeGruppe', 'PendentBei', 'FristBis', 'Departemente',
#        'Ablaufschritte', 'VerknuepfteGeschaefte', 'gid',
#        'Erstunterzeichnender.Id', 'Erstunterzeichnender.Name',
#        'Erstunterzeichnender.Vorname', 'Erstunterzeichnender.Titel',
#        'Erstunterzeichnender.Partei', 'Erstunterzeichnender.Wahlkreis',
#        'Erstunterzeichnender.WahlkreisOrderBy',
#        'ZweiterErstunterzeichnender.Id', 'ZweiterErstunterzeichnender.Name',
#        'ZweiterErstunterzeichnender.Vorname',
#        'ZweiterErstunterzeichnender.Titel',
#        'ZweiterErstunterzeichnender.Partei',
#        'ZweiterErstunterzeichnender.Wahlkreis',
#        'ZweiterErstunterzeichnender.WahlkreisOrderBy', 'Erstunterzeichnender',
#        'ZweiterErstunterzeichnender'],
#       dtype='object')

# %%
url_geschaefte = "https://www.gemeinderat-zuerich.ch/geschaefte/detailansicht-geschaeft"
df_deals_details_normalized['deals_details_url'] = url_geschaefte +'?gid='+ df_deals_details_normalized.gid

df_deals_details_normalized.head(2)
df_deals_details_normalized.columns
# Out:
# Index(['GeschaeftTitel', 'GeschaeftsJahr', 'GeschaeftsNummer', 'GeschaeftsArt',
#        'EinreichendeGruppe', 'PendentBei', 'FristBis', 'Departemente',
#        'Ablaufschritte', 'VerknuepfteGeschaefte', 'gid',
#        'Erstunterzeichnender.Id', 'Erstunterzeichnender.Name',
#        'Erstunterzeichnender.Vorname', 'Erstunterzeichnender.Titel',
#        'Erstunterzeichnender.Partei', 'Erstunterzeichnender.Wahlkreis',
#        'Erstunterzeichnender.WahlkreisOrderBy',
#        'ZweiterErstunterzeichnender.Id', 'ZweiterErstunterzeichnender.Name',
#        'ZweiterErstunterzeichnender.Vorname',
#        'ZweiterErstunterzeichnender.Titel',
#        'ZweiterErstunterzeichnender.Partei',
#        'ZweiterErstunterzeichnender.Wahlkreis',
#        'ZweiterErstunterzeichnender.WahlkreisOrderBy', 'Erstunterzeichnender',
#        'ZweiterErstunterzeichnender', 'deals_details_url'],
#       dtype='object')

# %%
df_deals_details_normalized.to_excel('glp_deals_details_normalized.xlsx')

# %%
#deals_details

# %% [markdown]
# So können z.B. die Ablaufschritte einzeln noch herausgelesen werden

# %%
df_deals_details_normalized2 = pd.json_normalize(
    deals_details, 
    record_path=['Ablaufschritte'], 
    meta=[['Id', 'Name', 'Vorname']],
    meta_prefix='meta-',
    record_prefix='path-',
    errors='ignore' 
)

# %%
#deals_details
df_deals_details_normalized2.head(2)
#df_deals_details_normalized2.columns
# Out:
#             path-Datum             path-Created                   path-Titel  \
# 0  2022-04-06T00:00:00  2022-04-06T21:26:44.467      Eingang, Frist 3 Monate
# 1  2022-04-06T00:00:00  2022-04-07T10:48:42.753  Dringlicherklärung, erfolgt
#
#                                path-Protokolleintrag  \
# 0  <p style="margin: 0px 0px 0px 0px;text-align: ...
# 1  <p style="margin: 0px 0px 0px 0px;text-align: ...
#
#                          path-AblaufschrittDokumente  path-BeschlussNrGR  \
# 0  [{'Dokumenttitel': '2022_0133.pdf', 'Id': '1f7...              5216.0
# 1                                                 []              5191.0
#
#    path-SitzungsNr path-AudioLink path-AudioLinkText meta-Id.Name.Vorname
# 0            193.0           None               None                  NaN
# 1            193.0           None               None                  NaN
