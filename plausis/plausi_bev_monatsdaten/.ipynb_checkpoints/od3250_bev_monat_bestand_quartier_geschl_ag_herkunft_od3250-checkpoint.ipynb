# %% [markdown]
# # Testing
# ## Bevölkerung nach Monat, Stadtquartier, Geschlecht, Altersgruppe und Herkunft, seit 1998
# Datum: 08.12.2021

# %% [markdown]
# ### Importiere die notwendigen Packages

# %%
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
#from datetime import datetime
import datetime
import geopandas as gpd
import folium 
import plotly.express as px

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# ### Zeitvariabeln
# Bestimme den aktuellst geladenen Monat. Hier ist es der Stand vor 2 Monaten.
# Bestimme noch weitere evt. sinnvolle Zeitvariabeln.
#
# Zum Unterschied zwischen import datetime und from datedtime import datetime, siehe https://stackoverflow.com/questions/15707532/import-datetime-v-s-from-datetime-import-datetime
#
# Zuerst die Zeitvariabeln als Strings

# %%
#today_date = datetime.date.today()
#date_time = datetime.datetime.strptime(date_time_string, '%Y-%m-%d %H:%M')
now = datetime.date.today()
date_today = now.strftime("%Y-%m-%d")
year_today = now.strftime("%Y")
month_today = now.strftime("%m")
day_today = now.strftime("%d")

# %% [markdown]
# Und hier noch die Zeitvariabeln als Integers:
# - `aktuellesJahr`
# - `aktuellerMonat`: Der gerade jetzt aktuelle Monat
# - `selectedMonat`: Der aktuellste Monat in den Daten. In der Regel zwei Monate her.

# %%
#now = datetime.now() 
int_times = now.timetuple()

aktuellesJahr = int_times[0]
aktuellerMonat = int_times[1]
selectedMonat = int_times[1]-2

print(aktuellesJahr, 
      aktuellerMonat,
    'datenstand: ', selectedMonat,
     int_times)
# Out:
# 2022 2 datenstand:  0 time.struct_time(tm_year=2022, tm_mon=2, tm_mday=18, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=49, tm_isdst=-1)

# %% [markdown]
# Berechne die Variable Epoche um später das SAS-Datum in ein Unix-Datum umzuwandeln. Bei SAS beginnt die Epoche am 1.1.1960. Bei Unix am 1.1.1970.
# Diese Variable wird beim CSV-Import benötigt.

# %%
epoch = datetime.datetime(1960, 1, 1)

# %% [markdown]
# ### Importiere einen Datensatz
#
# - Beachte dabei die Notation des Pfades...
# - Definiere mal aktuell noch keine weiteren Parameter beim Import

# %% [markdown]
# **Dataset auf INTEG Datenkatalog**:  https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bev_monat_bestand_quartier_geschl_ag_herkunft_od3250
#
# **Dataset auf PROD Datenkatalog**:  https://data.stadt-zuerich.ch/dataset/bev_monat_bestand_quartier_geschl_ag_herkunft_od3250

# %%
#Die Datasets sind nur zum Testen auf INT-DWH-Dropzone. Wenn der Test vorbei ist, sind sie auf PROD. 
# Über den Status kann man einfach switchen

status = "integ";
print(status)
# Out:
# integ

# %%
# Filepath
if status == "prod":
    #fp = r"//szh.loc/ssz/applikationen/OGD_Dropzone/DWH/bev_monat_bestand_quartier_geschl_ag_herkunft_od3250/BEV325OD3250.csv"
    fp = r"https://data.stadt-zuerich.ch/dataset/bev_monat_bestand_quartier_geschl_ag_herkunft_od3250/download/BEV325OD3250.csv"
else:
    fp = r"//szh.loc/ssz/applikationen/OGD_Dropzone/INT_DWH/bev_monat_bestand_quartier_geschl_ag_herkunft_od3250/BEV325OD3250.csv"
    #fp = r"https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bev_monat_bestand_quartier_geschl_ag_herkunft_od3250/download/BEV325OD3250.csv"


print(fp)
# Out:
# //szh.loc/ssz/applikationen/OGD_Dropzone/INT_DWH/bev_monat_bestand_quartier_geschl_ag_herkunft_od3250/BEV325OD3250.csv

# %% [markdown]
# Beachte, wie das SAS Datum (ohne Format) in ein UNIX Datum umgerechnet und als Datumsformat dargestellt wird! Siehe dazu `https://stackoverflow.com/questions/26923564/convert-sas-numeric-to-python-datetime`

# %%
# Read the data
data2betested = pd.read_csv(
    fp, 
    sep=',',
    parse_dates=['StichtagDat'],
    # KONVERTIERE DAS SAS DATUM IN EIN UNIXDATUM UND FORMATIERE ES
    date_parser=lambda s: epoch + datetime.timedelta(days=int(s)),
    low_memory=False    
    )

print('done')
# Out:
# done

# %% [markdown]
# In der Folge ein paar erste Tests:

# %% [markdown]
#  - 1) Zeige eine kurze Vorschau der importierten Daten
#  - 2) Weise die Datentypen aus
#  - 3) Zeige die Shape (Umfang) des Datensatzes an

# %%
data2betested.sort_values(by=['StichtagDatJahr','StichtagDatMM'], ascending=False).head(3)
# Out:
#         StichtagDatJahr  StichtagDatMM StichtagDatMonat StichtagDat  SexCd   SexLang  \
# 194897             2021             12         Dezember  2021-12-31      1  männlich
# 194898             2021             12         Dezember  2021-12-31      1  männlich
# 194899             2021             12         Dezember  2021-12-31      1  männlich
#
#         AlterV20Sort  ... KreisCd  KreisLang QuarCd     QuarLang DatenstandCd  DatenstandLang  \
# 194897             1  ...       1    Kreis 1     11      Rathaus            P    Provisorisch
# 194898             1  ...       1    Kreis 1     12  Hochschulen            P    Provisorisch
# 194899             1  ...       1    Kreis 1     13    Lindenhof            P    Provisorisch
#
#        AnzBestWir
# 194897        119
# 194898         27
# 194899         40
#
# [3 rows x 17 columns]

# %%
data2betested.dtypes
# Out:
# StichtagDatJahr              int64
# StichtagDatMM                int64
# StichtagDatMonat            object
# StichtagDat         datetime64[ns]
# SexCd                        int64
# SexLang                     object
# AlterV20Sort                 int64
# AlterV20Kurz                object
# HerkunftCd                   int64
# HerkunftLang                object
# KreisCd                      int64
# KreisLang                   object
# QuarCd                       int64
# QuarLang                    object
# DatenstandCd                object
# DatenstandLang              object
# AnzBestWir                   int64
# dtype: object

# %%
data2betested.shape
# Out:
# (195576, 17)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.describe()
# Out:
#        StichtagDatJahr  StichtagDatMM  SexCd  AlterV20Sort  HerkunftCd  KreisCd  QuarCd  \
# count           195576         195576 195576        195576      195576   195576  195576
# mean              2010              6      2             3           1        6      66
# std                  7              3      1             1           0        5      44
# min               1998              1      1             1           1        1      11
# 25%               2004              3      1             2           1        3      33
# 50%               2010              6      2             3           1        7      71
# 75%               2016              9      2             4           2        9      92
# max               2021             12      2             5           2       99     999
#
#        AnzBestWir
# count      195576
# mean          573
# std           614
# min             0
# 25%           104
# 50%           377
# 75%           822
# max          3737

# %% [markdown]
# Wie viele Nullwerte gibt es im Datensatz?

# %%
data2betested.isnull().sum()
# Out:
# StichtagDatJahr     0
# StichtagDatMM       0
# StichtagDatMonat    0
# StichtagDat         0
# SexCd               0
# SexLang             0
# AlterV20Sort        0
# AlterV20Kurz        0
# HerkunftCd          0
# HerkunftLang        0
# KreisCd             0
# KreisLang           0
# QuarCd              0
# QuarLang            0
# DatenstandCd        0
# DatenstandLang      0
# AnzBestWir          0
# dtype: int64

# %% [markdown]
# ### Verwende das Datum als Index
#
# While we did already parse the `datetime` column into the respective datetime type, it currently is just a regular column.
# **To enable quick and convenient queries and aggregations, we need to turn it into the index of the DataFrame**

# %%
data2betested = data2betested.set_index("StichtagDat")
#data2betested = data2betested.drop(columns=["StichtagDatMM"])

# %%
data2betested.info()
data2betested.index.day.unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 195576 entries, 1998-01-31 to 2021-12-31
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   StichtagDatJahr   195576 non-null  int64
#  1   StichtagDatMM     195576 non-null  int64
#  2   StichtagDatMonat  195576 non-null  object
#  3   SexCd             195576 non-null  int64
#  4   SexLang           195576 non-null  object
#  5   AlterV20Sort      195576 non-null  int64
#  6   AlterV20Kurz      195576 non-null  object
#  7   HerkunftCd        195576 non-null  int64
#  8   HerkunftLang      195576 non-null  object
#  9   KreisCd           195576 non-null  int64
#  10  KreisLang         195576 non-null  object
#  11  QuarCd            195576 non-null  int64
#  12  QuarLang          195576 non-null  object
#  13  DatenstandCd      195576 non-null  object
#  14  DatenstandLang    195576 non-null  object
#  15  AnzBestWir        195576 non-null  int64
# dtypes: int64(8), object(8)
# memory usage: 25.4+ MB
# Int64Index([31, 28, 30, 29], dtype='int64', name='StichtagDat')

# %% [markdown]
# ### Einfache Visualisierungen zur Plausi

# %% [markdown]
# Exploriere die Daten mit Pivottable.JS

# %%
from pivottablejs import pivot_ui

pivot_ui(data2betested)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Zeitpunkte und Zeiträume abfragen
#
# A particular powerful feature of the Pandas DataFrame is its indexing capability that also works using time-based entities, such as dates and times. We have already created the index above, so let's put it to use.

# %%
data2betested.loc["2021-12"].head(2)
#data2betested.loc["2021-10-31":"2021-11-30"].head(2)
# Out:
#              StichtagDatJahr  StichtagDatMM StichtagDatMonat  SexCd   SexLang  AlterV20Sort  \
# StichtagDat
# 2021-12-31              2021             12         Dezember      1  männlich             1
# 2021-12-31              2021             12         Dezember      1  männlich             1
#
#             AlterV20Kurz  ...  KreisCd KreisLang  QuarCd     QuarLang  DatenstandCd  \
# StichtagDat               ...
# 2021-12-31          0-19  ...        1   Kreis 1      11      Rathaus             P
# 2021-12-31          0-19  ...        1   Kreis 1      12  Hochschulen             P
#
#             DatenstandLang AnzBestWir
# StichtagDat
# 2021-12-31    Provisorisch        119
# 2021-12-31    Provisorisch         27
#
# [2 rows x 16 columns]

# %% [markdown]
# ### Aggriere Werte nach Zeitausschnitten
#
# Mit den Funktionen zur Zeit kann einfach zwischen Stunden, Tagen, Monaten, etc. gewechselt und aggregiert werden.
# Da die Daten bereits aggregiert nach Monaten sind, macht das hier keinen Sinn.
# Untenstehendes also nur als BSP

# %%
# first we create the sums per week
weekly_sums = data2betested.resample("W").sum()
# then we generate the weekly means for each quarter
data2betested_sel = data2betested[["SexCd","HerkunftCd","AnzBestWir"]]
quarterly_sums = data2betested_sel.resample("Q").sum()
# for readability we'll revert the values back to integers
quarterly_sums.astype(int).head(1)
# Out:
#              SexCd  HerkunftCd  AnzBestWir
# StichtagDat
# 1998-03-31    3057        3054     1077987

# %% [markdown]
# ### Visualisierungen nach Zeitausschnitten

# %%
data2betested.info()
#data2betested
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 195576 entries, 1998-01-31 to 2021-12-31
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   StichtagDatJahr   195576 non-null  int64
#  1   StichtagDatMM     195576 non-null  int64
#  2   StichtagDatMonat  195576 non-null  object
#  3   SexCd             195576 non-null  int64
#  4   SexLang           195576 non-null  object
#  5   AlterV20Sort      195576 non-null  int64
#  6   AlterV20Kurz      195576 non-null  object
#  7   HerkunftCd        195576 non-null  int64
#  8   HerkunftLang      195576 non-null  object
#  9   KreisCd           195576 non-null  int64
#  10  KreisLang         195576 non-null  object
#  11  QuarCd            195576 non-null  int64
#  12  QuarLang          195576 non-null  object
#  13  DatenstandCd      195576 non-null  object
#  14  DatenstandLang    195576 non-null  object
#  15  AnzBestWir        195576 non-null  int64
# dtypes: int64(8), object(8)
# memory usage: 25.4+ MB

# %% [markdown]
# #### Entwicklung Wohnbevölkerung nach Stadtkreis

# %%
#myAgg = data2betested.loc["2008-11-30":"2021-10-31"]
myAgg = data2betested \
    .groupby(['StichtagDat','StichtagDatJahr', 'StichtagDatMM','KreisLang']) \
    .agg(sum_WBev=('AnzBestWir', 'sum')) \
    .sort_values('sum_WBev', ascending=False) 

myAgg.reset_index().head(2)
# Out:
#   StichtagDat  StichtagDatJahr  StichtagDatMM KreisLang  sum_WBev
# 0  2021-12-31             2021             12  Kreis 11     76975
# 1  2021-11-30             2021             11  Kreis 11     76922

# %%
myTitle="Wohnbevölkerung nach Stadtkreis"

highlight = alt.selection(type='single', on='mouseover',
                          fields=['KreisLang'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(myAgg.reset_index().query('sum_WBev>100'), title=myTitle).encode(
    x=alt.X('StichtagDat', axis=alt.Axis(title='Jahr'))# , axis=alt.Axis(format='%', title='percentage')
    , y=alt.X('sum_WBev', axis=alt.Axis(title='Anz. Personen'))
    , color=alt.Color('KreisLang', legend=alt.Legend(title="Stadtkreise", orient="right"))  
    ,tooltip=['StichtagDat', 'KreisLang', 'sum_WBev']    
)
points = base.mark_circle().encode(
    opacity=alt.value(0.75)
).add_selection(
    highlight
).properties(
    width=900 , height=350
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(0.5), alt.value(4))
).interactive()

lines + points
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### Entwicklung nach Alter

# %%
#myAgg = data2betested.loc["2008-11":"2021-11"] \
myAgg = data2betested \
    .groupby(['StichtagDat','StichtagDatJahr', 'StichtagDatMM', 'AlterV20Kurz']) \
    .agg(sum_WBev=('AnzBestWir', 'sum')) \
    .sort_values('sum_WBev', ascending=False) 

myAgg.reset_index().head(2)
# Out:
#   StichtagDat  StichtagDatJahr  StichtagDatMM AlterV20Kurz  sum_WBev
# 0  2019-11-30             2019             11        20-39    163622
# 1  2019-10-31             2019             10        20-39    163512

# %%
myTitle="Wohnbevölkerung nach Altersgruppen"
highlight = alt.selection(type='single', on='mouseover',
                          fields=['AlterV20Kurz'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(myAgg.reset_index().query('sum_WBev>100'), title=myTitle).encode(
    x=alt.X('StichtagDat', axis=alt.Axis(title='Jahr'))# , axis=alt.Axis(format='%', title='percentage')
    , y=alt.X('sum_WBev', axis=alt.Axis(title='Anz. Personen'))
    , color=alt.Color('AlterV20Kurz', legend=alt.Legend(title="Altersgruppen"))  
    ,tooltip=['StichtagDat', 'AlterV20Kurz', 'sum_WBev']    
)
points = base.mark_circle().encode(
    opacity=alt.value(0.75)
).add_selection(
    highlight
).properties(
    width=900 , height=350
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(0.5), alt.value(4))
).interactive()

lines + points
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### Entwicklung nach Heimat

# %%
#myAgg = data2betested.loc["2008-11":"2021-11"] \
myAgg = data2betested \
    .groupby(['StichtagDat','StichtagDatJahr', 'StichtagDatMM', 'HerkunftLang']) \
    .agg(sum_WBev=('AnzBestWir', 'sum')) \
    .sort_values('sum_WBev', ascending=False) 

myAgg.reset_index().head(2)
# Out:
#   StichtagDat  StichtagDatJahr  StichtagDatMM  HerkunftLang  sum_WBev
# 0  2021-11-30             2021             11  Schweizer/in    296201
# 1  2021-12-31             2021             12  Schweizer/in    295989

# %%
myTitle="Wohnbevölkerung nach Herkunft"
highlight = alt.selection(type='single', on='mouseover',
                          fields=['HerkunftLang'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(myAgg.reset_index().query('sum_WBev>100'), title=myTitle).encode(
    x=alt.X('StichtagDat', axis=alt.Axis(title='Jahr'))# , axis=alt.Axis(format='%', title='percentage')
    , y=alt.X('sum_WBev', axis=alt.Axis(title='Anz. Personen'))
    , color=alt.Color('HerkunftLang', legend=alt.Legend(title="Herkunft"))  
    ,tooltip=['StichtagDat', 'HerkunftLang', 'sum_WBev']    
)
points = base.mark_circle().encode(
    opacity=alt.value(0.75)
).add_selection(
    highlight
).properties(
    width=900 , height=350
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(0.5), alt.value(4))
).interactive()

lines + points
# Out:
# alt.LayerChart(...)

# %%
data2betested.dtypes
# Out:
# StichtagDatJahr      int64
# StichtagDatMM        int64
# StichtagDatMonat    object
# SexCd                int64
# SexLang             object
# AlterV20Sort         int64
# AlterV20Kurz        object
# HerkunftCd           int64
# HerkunftLang        object
# KreisCd              int64
# KreisLang           object
# QuarCd               int64
# QuarLang            object
# DatenstandCd        object
# DatenstandLang      object
# AnzBestWir           int64
# dtype: object

# %% [markdown]
# ### Daten in interaktiver Treemap zeigen
# Dazu gibt es eine sehr nützliche Webseite https://plotly.com/python/treemaps/
# Zu Farbskalen, siehe: https://plotly.com/python/builtin-colorscales/

# %% [markdown]
# #### Aktueller Bestand der WBev nach Stadtkreis, Quartier, Alter und Herkunft

# %%
myTreemapAgg = data2betested.loc["2021-12"]  \
    .groupby(['StichtagDat','StichtagDatJahr', 'StichtagDatMM', 'KreisLang','QuarLang','HerkunftLang', 'AlterV20Kurz' ]) \
    .agg(sum_WBev=('AnzBestWir', 'sum')) \
    .sort_values('sum_WBev', ascending=False) 

myTreemapAgg.reset_index().head(2)
# Out:
#   StichtagDat  StichtagDatJahr  StichtagDatMM KreisLang    QuarLang  HerkunftLang AlterV20Kurz  \
# 0  2021-12-31             2021             12   Kreis 9  Altstetten  Schweizer/in        20-39
# 1  2021-12-31             2021             12   Kreis 9  Altstetten  Ausländer/in        20-39
#
#    sum_WBev
# 0      7157
# 1      6110

# %%
fig = px.treemap(myTreemapAgg.reset_index(), path=[px.Constant("WBev nach Stadtkreis, Quartier, Alter und Herkunft"), 'KreisLang','QuarLang','HerkunftLang', 'AlterV20Kurz']
                 , values='sum_WBev'
                 , color='sum_WBev'
                 ## bei discrete scales (bei Klassen und Strings):                 
                 #, color_discrete_map={'(?)':'lightgrey','EVP':'gold', 'SP':'#FF3030', 'PdA':'#EE3B3B', 'Grüne':'#A2CD5A','GLP':'#CAFF70','Die Mitte':'orange','FDP':'#104E8B','AL':'deeppink','SVP':'forestgreen', 'FL ZÜRI':'#8B864E','Volt':'#lightblue' }                
                 ## bei continuous scales (bei Zahlenwerten):
                , color_continuous_scale='Blues'
                #, color_continuous_midpoint=np.average(df['AnzBestWir'], weights=df['AnzBestWir'])  
                 #,height=400
                 #,width=1500                 
                )
fig.update_traces(root_color="grey")
fig.update_layout(margin = dict(t=50, l=25, r=250, b=25))
fig.show()

# %% [markdown]
# #### Aktueller Bestand der WBev nach Stadtkreis, Alter und Herkunft

# %%
myTreemapAgg = data2betested.loc["2021-12"]  \
    .groupby(['StichtagDat','StichtagDatJahr', 'StichtagDatMM', 'KreisLang','HerkunftLang', 'AlterV20Kurz' ]) \
    .agg(sum_WBev=('AnzBestWir', 'sum')) \
    .sort_values('sum_WBev', ascending=False) 

myTreemapAgg.reset_index().head(2)
# Out:
#   StichtagDat  StichtagDatJahr  StichtagDatMM KreisLang  HerkunftLang AlterV20Kurz  sum_WBev
# 0  2021-12-31             2021             12  Kreis 11  Schweizer/in        20-39     15552
# 1  2021-12-31             2021             12  Kreis 11  Ausländer/in        20-39     14394

# %%
fig = px.treemap(myTreemapAgg.reset_index()
                 , path=[px.Constant("WBev nach Alter, Stadtkreis und Herkunft"), 'AlterV20Kurz','KreisLang','HerkunftLang']
                 , values='sum_WBev'
                 , color='sum_WBev'
                 ## bei discrete scales (bei Klassen und Strings):                 
                 #, color_discrete_map={'(?)':'lightgrey','EVP':'gold', 'SP':'#FF3030', 'PdA':'#EE3B3B', 'Grüne':'#A2CD5A','GLP':'#CAFF70','Die Mitte':'orange','FDP':'#104E8B','AL':'deeppink','SVP':'forestgreen', 'FL ZÜRI':'#8B864E','Volt':'#lightblue' }                
                 ## bei continuous scales (bei Zahlenwerten):
                , color_continuous_scale='PuBuGn'
                #, color_continuous_midpoint=np.average(df['AnzBestWir'], weights=df['AnzBestWir']) 
                 #,height=400
                 #,width=1500
                )
fig.update_traces(root_color="grey")
fig.update_layout(margin = dict(t=50, l=25, r=250, b=25))#, title="WBev nach Alter, Stadtkreis und Herkunft")
fig.show()

# %% [markdown]
# Liniendiagramm
# [Link zur Doku](https://altair-viz.github.io/gallery/multiline_highlight.html)

# %% [markdown]
# ### Test: Choroplethenkarte
# Importiere die Geodaten als GeoJSON

# %%
# Read abt. Geopandas https://geopandas.org/docs/user_guide/io.html
# Wenn die Daten lokal agelegt sind, dann kannst Du folgendes machen:
##input_stadtquartiere = r"//szh.loc/ssz/data/GIS/Daten/Vektor/_aktuell/stzh.adm_statistische_quartiere_map.json"
##df_stadtquartiere = gpd.read_file(input_stadtquartiere)
##df_stadtquartiere.head(2)
#df_stadtkreise.dtypes

geojson_url = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Statistische_Quartiere?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_statistische_quartiere_map"
df_adm_statistische_quartiere_map = gpd.read_file(geojson_url)

df_adm_statistische_quartiere_map.head(5)
# Out:
#                                  id    kname  knr  objectid objid       qname  qnr  \
# 0  adm_statistische_quartiere_map.1  Kreis 7    7         1    34  Hirslanden   73
# 1  adm_statistische_quartiere_map.2  Kreis 8    8         2    33     Weinegg   83
# 2  adm_statistische_quartiere_map.3  Kreis 8    8         3    32   Mühlebach   82
# 3  adm_statistische_quartiere_map.4  Kreis 8    8         4    31     Seefeld   81
# 4  adm_statistische_quartiere_map.7  Kreis 4    4         7    16        Werd   41
#
#                                             geometry
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...
# 1  POLYGON ((8.55670 47.36405, 8.55672 47.36403, ...
# 2  POLYGON ((8.55423 47.36456, 8.55426 47.36452, ...
# 3  POLYGON ((8.54795 47.36500, 8.54805 47.36489, ...
# 4  POLYGON ((8.53300 47.37394, 8.53299 47.37392, ...

# %% [markdown]
# Joine die importierten statistischen Daten des aktuellen Jahres zum Geodatensatz:
#
# *Siehe dazu Doku zu [Geopandas](https://geopandas.org/docs/user_guide/mergingdata.html)*

# %%
akt_wbev_quart = data2betested.loc["2021-11"].groupby(
    ['StichtagDatJahr','StichtagDatMM','QuarCd','QuarLang']
).agg(
    {'AnzBestWir':'sum'}
)
akt_wbev_quart.head()
# Out:
#                                                   AnzBestWir
# StichtagDatJahr StichtagDatMM QuarCd QuarLang
# 2021            11            11     Rathaus            3283
#                               12     Hochschulen         718
#                               13     Lindenhof          1033
#                               14     City                835
#                               21     Wollishofen       20002

# %%
# Rename attribute stznr to StatZoneSort, so the IDs have the same name
stadtquartiere_shapes = df_adm_statistische_quartiere_map[['geometry', 'qnr', 'qname', 'knr']].rename(columns={'qnr': 'QuarCd'})

# Merge with `merge` method on shared variable (stznr und StatZoneSort):
stadtquartiere_shapes_joined = stadtquartiere_shapes.merge(akt_wbev_quart, on='QuarCd')

stadtquartiere_shapes_joined.head(2)
# Out:
#                                             geometry  QuarCd       qname  knr  AnzBestWir
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...      73  Hirslanden    7        7342
# 1  POLYGON ((8.55670 47.36405, 8.55672 47.36403, ...      83     Weinegg    8        5564

# %%
# Plot by StatQuartiere
# Weitere Schemes: scheme='quantiles', scheme='fisherjenks', scheme='natural_breaks',

stadtquartiere_shapes_joined.plot(column='AnzBestWir', cmap='viridis', scheme='natural_breaks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

stadtquartiere_shapes_joined.plot(column='AnzBestWir', cmap='plasma', scheme='fisherjenks', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html
stadtquartiere_shapes_joined.plot(column='AnzBestWir', cmap='cool', scheme='quantiles', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

#
#Neuere Gallerie: https://matplotlib.org/stable/gallery/index.html

# %% [raw]
# fig, ax = plt.subplots(1, 1)
#
# statzonen_shapes_aktJahr.plot(column='AnzWhg', ax=ax, legend=True, legend_kwds={'label': "Anzahl Personen",'orientation': "horizontal"})

# %% [markdown]
# Noch zu prüfen, folgendes schöne Beispiel: https://docs.bokeh.org/en/latest/docs/user_guide/interaction/legends.html
#
# Konkrete Beispiele von Bookeh in Jupyter NB: https://docs.bokeh.org/en/latest/docs/user_guide/jupyter.html

# %% [markdown]
# **Sharepoint als gecheckt markieren!**

# %% [markdown]
# Record auf Sharepoint: **[Link](http://kollaboration.intranet.stzh.ch/orga/ssz-produkte/Lists/SASA_Outputs/EditForm.aspx?ID=157&Source=%2Forga%2Fssz%2Dprodukte%2FLists%2FSASA%5FOutputs)**
