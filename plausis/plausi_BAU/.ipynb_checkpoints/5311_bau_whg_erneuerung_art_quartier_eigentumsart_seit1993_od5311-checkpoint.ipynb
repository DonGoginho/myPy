# %% [markdown]
# # Testing
# ### Bauliche Erneuerung nach Art der Erneuerung, Eigentumsgruppe und Stadtquartier seit 1993
# Datum: 08.02.2022

# %% [markdown]
# ### Importiere die notwendigen Packages

# %%
#%pip install geopandas altair fiona requests folium mplleaflet contextily seaborn datetime plotly

# %%
import pandas as pd
import pivottablejs
from pivottablejs import pivot_ui
import numpy as np
import altair as alt
import matplotlib.pyplot as plt
#from datetime import datetime
import datetime
import geopandas as gpd
import folium 
import plotly.express as px
import seaborn as sns

# %% [markdown]
# Definiere Settings. Hier das Zahlenformat von Float-Werten (z.B. *'{:,.2f}'.format* mit Komma als Tausenderzeichen),

# %%
pd.options.display.float_format = '{:.0f}'.format
pd.set_option('display.width', 100)
pd.set_option('display.max_columns', 15)

# %% [markdown]
# ### Zeitvariabeln
# Bestimme den aktuellst geladenen Monat. Hier ist es der Stand vor 2 Monaten.
# Bestimme noch weitere evt. sinnvolle Zeitvariabeln.
#
# Zum Unterschied zwischen import datetime und from datedtime import datetime, siehe https://stackoverflow.com/questions/15707532/import-datetime-v-s-from-datetime-import-datetime
#
# Zuerst die Zeitvariabeln als Strings

# %%
#today_date = datetime.date.today()
#date_time = datetime.datetime.strptime(date_time_string, '%Y-%m-%d %H:%M')
now = datetime.date.today()
date_today = now.strftime("%Y-%m-%d")
year_today = now.strftime("%Y")
month_today = now.strftime("%m")
day_today = now.strftime("%d")

# %% [markdown]
# Und hier noch die Zeitvariabeln als Integers:
# - `aktuellesJahr`
# - `aktuellerMonat`: Der gerade jetzt aktuelle Monat
# - `selectedMonat`: Der aktuellste Monat in den Daten. In der Regel zwei Monate her.

# %%
#now = datetime.now() 
int_times = now.timetuple()

aktuellesJahr = int_times[0]
aktuellerMonat = int_times[1]
selectedMonat = int_times[1]-2

print(aktuellesJahr, 
      aktuellerMonat,
    'datenstand: ', selectedMonat,
     int_times)
# Out:
# 2022 2 datenstand:  0 time.struct_time(tm_year=2022, tm_mon=2, tm_mday=8, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=39, tm_isdst=-1)

# %% [markdown]
# Berechne die Variable Epoche um später das SAS-Datum in ein Unix-Datum umzuwandeln. Bei SAS beginnt die Epoche am 1.1.1960. Bei Unix am 1.1.1970.
# Diese Variable wird beim CSV-Import benötigt.

# %%
epoch = datetime.datetime(1960, 1, 1)

# %% [markdown]
# ### Importiere einen Datensatz
#
# - Beachte dabei die Notation des Pfades...
# - Definiere mal aktuell noch keine weiteren Parameter beim Import

# %% [markdown]
# **Dataset auf INTEG Datenkatalog**:  https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bau_whg_erneuerung_art_quartier_eigentumsart_seit1993_od5311
#
# **Dataset auf PROD Datenkatalog**:  https://data.stadt-zuerich.ch/dataset/bbau_whg_erneuerung_art_quartier_eigentumsart_seit1993_od5311

# %%
#Die Datasets sind nur zum Testen auf INT-DWH-Dropzone. Wenn der Test vorbei ist, sind sie auf PROD. 
# Über den Status kann man einfach switchen

status = "integ";
print(status)
# Out:
# prod

# %%
# Filepath
if status == "prod":
    fp = r"https://data.stadt-zuerich.ch/dataset/bau_whg_erneuerung_art_quartier_eigentumsart_seit1993_od5311/download/BAU531OD5311.csv"
else:
    fp = r"\\szh\ssz\applikationen\OGD_Dropzone\INT_DWH\bau_whg_erneuerung_art_quartier_eigentumsart_seit1993_od5311\BAU531OD5311.csv"   

print(fp)
# Out:
# https://data.stadt-zuerich.ch/dataset/bau_whg_erneuerung_art_quartier_eigentumsart_seit1993_od5311/download/BAU531OD5311.csv

# %%
# Read the data
data2betested = pd.read_csv(
    fp
    , sep=','
    ,parse_dates=['Jahr']
    # KONVERTIERE DAS SAS DATUM IN EIN UNIXDATUM UND FORMATIERE ES
    #, date_parser=lambda s: epoch + datetime.timedelta(days=int(s))
    ,low_memory=False    
    )

print('done')
# Out:
# done

# %% [markdown]
# In gewissen Datensätzen kommen noch die Zeilen `Jahr` anstatt `StichDatJahr` vor. Diese werden hier für solche Fälle ergänzt.

# %%
if set(['Jahr']).issubset(data2betested.columns):
    data2betested['StichtagDatJahr'] = data2betested['Jahr']

# %%
#data2betested.dtypes

# %% [markdown]
# In der Folge ein paar erste Tests:

# %% [markdown]
#  - 1) Zeige eine kurze Vorschau der importierten Daten
#  - 2) Weise die Datentypen aus
#  - 3) Zeige die Shape (Umfang) des Datensatzes an

# %%
#data2betested.head(6)

# %%
data2betested.dtypes
# Out:
# Jahr                  datetime64[ns]
# QuarSort                       int64
# QuarLang                      object
# KreisSort                      int64
# KreisLang                     object
# EigGruSort                     int64
# EigGruLang                    object
# WhgUmb                         int64
# WhgAbb                         int64
# WhgBestandRelevant             int64
# StichtagDatJahr       datetime64[ns]
# dtype: object

# %%
data2betested.shape
# Out:
# (3726, 11)

# %% [markdown]
# Beschreibe einzelne Attribute

# %%
data2betested.describe()
# Out:
#        QuarSort  KreisSort  EigGruSort  WhgUmb  WhgAbb  WhgBestandRelevant
# count      3726       3726        3726    3726    3726                3726
# mean         66          6           3      18       4                1461
# std          36          4           2      33      16                1821
# min          11          1           1       0       0                   4
# 25%          33          3           2       0       0                 268
# 50%          71          7           3       3       0                 756
# 75%          92          9           5      23       0                2002
# max         123         12           9     413     273               13781

# %% [markdown]
# Wie viele Nullwerte gibt es im Datensatz?

# %%
data2betested.isnull().sum()
# Out:
# Jahr                  0
# QuarSort              0
# QuarLang              0
# KreisSort             0
# KreisLang             0
# EigGruSort            0
# EigGruLang            0
# WhgUmb                0
# WhgAbb                0
# WhgBestandRelevant    0
# StichtagDatJahr       0
# dtype: int64

# %% [markdown]
# ### Verwende das Datum als Index
#
# While we did already parse the `datetime` column into the respective datetime type, it currently is just a regular column.
# **To enable quick and convenient queries and aggregations, we need to turn it into the index of the DataFrame**

# %%
data2betested = data2betested.set_index("StichtagDatJahr")

# %%
data2betested.info()
data2betested.index.day.unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3726 entries, 1993-01-01 to 2021-01-01
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Jahr                3726 non-null   datetime64[ns]
#  1   QuarSort            3726 non-null   int64
#  2   QuarLang            3726 non-null   object
#  3   KreisSort           3726 non-null   int64
#  4   KreisLang           3726 non-null   object
#  5   EigGruSort          3726 non-null   int64
#  6   EigGruLang          3726 non-null   object
#  7   WhgUmb              3726 non-null   int64
#  8   WhgAbb              3726 non-null   int64
#  9   WhgBestandRelevant  3726 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(3)
# memory usage: 320.2+ KB
# Int64Index([1], dtype='int64', name='StichtagDatJahr')

# %% [markdown]
# ### Einfache Visualisierungen zur Plausi

# %% [markdown]
# Exploriere die Daten mit Pivottable.JS

# %%
from pivottablejs import pivot_ui

pivot_ui(data2betested)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Zeitpunkte und Zeiträume abfragen
#
# A particular powerful feature of the Pandas DataFrame is its indexing capability that also works using time-based entities, such as dates and times. We have already created the index above, so let's put it to use.

# %%
data2betested.loc["1993"].head(2)
#data2betested.loc["2021-10-31":"2021-11-30"].head(2)
# Out:
#                       Jahr  QuarSort     QuarLang  KreisSort KreisLang  EigGruSort  \
# StichtagDatJahr
# 1993-01-01      1993-01-01        11      Rathaus          1   Kreis 1           9
# 1993-01-01      1993-01-01        12  Hochschulen          1   Kreis 1           9
#
#                           EigGruLang  WhgUmb  WhgAbb  WhgBestandRelevant
# StichtagDatJahr
# 1993-01-01       Alle Eigentumsarten      20       0                1999
# 1993-01-01       Alle Eigentumsarten       0       0                 321

# %% [markdown]
# ### Visualisierungen nach Zeitausschnitten

# %% [markdown]
# #### Entwicklung Wohnungsbestand nach Bauperiode

# %%
data2betested.dtypes
# Out:
# Jahr                  datetime64[ns]
# QuarSort                       int64
# QuarLang                      object
# KreisSort                      int64
# KreisLang                     object
# EigGruSort                     int64
# EigGruLang                    object
# WhgUmb                         int64
# WhgAbb                         int64
# WhgBestandRelevant             int64
# dtype: object

# %%
myAgg = data2betested.loc["1993":"2021"]\
    .groupby(['StichtagDatJahr', 'EigGruSort', 'EigGruLang' ]) \
    .agg( sum_WhgBestandRelevant=('WhgBestandRelevant', 'sum'), sum_WhgUmb=('WhgUmb', 'sum'), sum_WhgAbb=('WhgAbb', 'sum')) \
    .sort_values('StichtagDatJahr', ascending=True) 
#myAgg.reset_index().head(3)

# %%
highlight = alt.selection(type='single', on='mouseover',
                          fields=['EigGruLang'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(myAgg.reset_index().query('sum_WhgBestandRelevant > 1'), title="Title").encode(
    x=alt.X('StichtagDatJahr', axis=alt.Axis(title='Jahr'))# , axis=alt.Axis(format='%', title='percentage')
    , y=alt.X('sum_WhgBestandRelevant', axis=alt.Axis(title='Anz. Wohnungen'))
    , color=alt.Color('EigGruLang', legend=alt.Legend(title="Eigentümergruppe", orient="right"))  
    ,tooltip=['StichtagDatJahr', 'EigGruLang','sum_WhgBestandRelevant', 'sum_WhgUmb','sum_WhgAbb' ]    
)
points = base.mark_circle().encode(
    opacity=alt.value(0.75)
).add_selection(
    highlight
).properties(
    width=750 , height=350
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(0.5), alt.value(4))
).interactive()

lines + points
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### Entwicklung der abgebrochenen Wohnungen nach Eigentumsgruppe

# %%
#data2betested.dtypes

# %%
#myAgg = data2betested.loc["2008-11-30":"2021-10-31"]
myAgg = data2betested.loc["1993":"2021"]\
    .groupby(['StichtagDatJahr', 'EigGruSort', 'EigGruLang' ]) \
    .agg( sum_WhgBestandRelevant=('WhgBestandRelevant', 'sum'), sum_WhgUmb=('WhgUmb', 'sum'), sum_WhgAbb=('WhgAbb', 'sum')) \
    .sort_values('StichtagDatJahr', ascending=True) 
#myAgg.reset_index().head(3)

# %%
highlight = alt.selection(type='single', on='mouseover',
                          fields=['EigGruLang'], nearest=True)
#x='date:StichtagDatJahr',
base = alt.Chart(myAgg.reset_index().query('sum_WhgAbb > 1'), title="Title").encode(
    x=alt.X('StichtagDatJahr', axis=alt.Axis(title='Jahr'))# , axis=alt.Axis(format='%', title='percentage')
    , y=alt.X('sum_WhgAbb', axis=alt.Axis(title='Anz. abgebrochener Wohnungen'))
    , color=alt.Color('EigGruLang', legend=alt.Legend(title="Eigentümergruppe", orient="right"))  
    ,tooltip=['StichtagDatJahr', 'EigGruLang','sum_WhgBestandRelevant', 'sum_WhgUmb','sum_WhgAbb' ]    
)
points = base.mark_circle().encode(
    opacity=alt.value(0.75)
).add_selection(
    highlight
).properties(
    width=750 , height=350
)
lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(0.5), alt.value(4))
).interactive()

lines + points
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### Barcharts mit Seaborn

# %%
#data2betested.dtypes

# %%
myAggBar = data2betested.loc["1993":"2021"]\
    .groupby(['StichtagDatJahr', 'EigGruSort', 'EigGruLang' ]) \
    .agg( sum_WhgBestandRelevant=('WhgBestandRelevant', 'sum'), sum_WhgUmb=('WhgUmb', 'sum'), sum_WhgAbb=('WhgAbb', 'sum')) \
    .sort_values('StichtagDatJahr', ascending=True) 
#myAggBar.reset_index().head(3)

# %%
#help(sns.catplot)

# %%
#Stile for the following sns graphs
sns.set_theme(style="whitegrid")

# %%
#sns.color_palette("flare", as_cmap=True)
myHist = sns.catplot(x="StichtagDatJahr"
            , y="sum_WhgAbb"
            , hue="EigGruLang"
            , kind="bar" #boxen, violin, --> wenn die aggregation nicht genau den werten in der grafik entspricht
            , palette="pastel" #, color="green"
            , height=5
            , aspect=2
            , order=None, legend_out=True
            ,data=myAggBar.reset_index()
           )
myHist.set_xlabels('Jahr', fontsize=11) # not set_label
myHist.set_ylabels('Anz. abgebrochene Wohnungen', fontsize=11)

# %%
#data2betested.dtypes

# %% [markdown]
# ##### Entwicklung der Erneuerung bei Wohnungen pro Kreis nach Eigentümergruppe

# %%
myAggBar = data2betested.loc["1993":"2021"]\
    .groupby(['StichtagDatJahr', 'EigGruSort', 'EigGruLang','KreisLang','KreisSort' ]) \
    .agg( sum_WhgBestandRelevant=('WhgBestandRelevant', 'sum'), sum_WhgUmb=('WhgUmb', 'sum'), sum_WhgAbb=('WhgAbb', 'sum')) \
    .sort_values('StichtagDatJahr', ascending=True) 
#myAggBar.reset_index().head(3)

# %%
g = sns.FacetGrid(myAggBar.reset_index(), col="KreisSort", hue="EigGruLang", col_wrap=4, height=3,)
#g.map(sns.scatterplot, "Jahr", "sum_WhgAbb", alpha=.8)
g.map(sns.lineplot, "StichtagDatJahr","sum_WhgAbb",alpha=.8)
g.add_legend()

g2 = sns.FacetGrid(myAggBar.reset_index(), col="KreisSort", hue="EigGruLang", col_wrap=4, height=3,)
#g2.map(sns.scatterplot, "Jahr", "sum_WhgUmb", alpha=.8)
g2.map(sns.lineplot, "StichtagDatJahr","sum_WhgUmb",alpha=.8)
g2.add_legend()

g3 = sns.FacetGrid(myAggBar.reset_index(), col="KreisSort", hue="EigGruLang", col_wrap=4, height=3,)
g3.map(sns.scatterplot, "sum_WhgUmb", "sum_WhgAbb", alpha=.8)
#g3.map(sns.lineplot, "StichtagDatJahr","sum_WhgBestandRelevant",alpha=.8)
g3.add_legend()

# %% [markdown]
# ### Daten in interaktiver Treemap zeigen
# Dazu gibt es eine sehr nützliche Webseite https://plotly.com/python/treemaps/
# Zu Farbskalen, siehe: https://plotly.com/python/builtin-colorscales/

# %% [markdown]
# #### Abgebrochene Wohnungen nach Quartier, Kreis und Eigentümerart 2011-2021

# %%
#data2betested.dtypes

# %%
myTreemapAgg = data2betested.loc["2011":"2021"]\
    .groupby(['StichtagDatJahr', 'EigGruSort', 'EigGruLang','KreisLang','KreisSort', 'QuarLang','QuarSort' ]) \
    .agg( sum_WhgBestandRelevant=('WhgBestandRelevant', 'sum'), sum_WhgUmb=('WhgUmb', 'sum'), sum_WhgAbb=('WhgAbb', 'sum')) \
    .sort_values('StichtagDatJahr', ascending=True) 

#myTreemapAgg.reset_index().head(3)

# %%
fig = px.treemap(myTreemapAgg.query('sum_WhgAbb >0').reset_index(), path=[px.Constant("Abgebrochene Wohnungen nach Quartier, Kreis und Eigentümerart 2021")
                                                                                      ,'KreisLang', 'QuarLang','EigGruLang', 'StichtagDatJahr']
                 , values='sum_WhgAbb'
                 , color='EigGruLang'
                 ## bei discrete scales (bei Klassen und Strings):                 
                 , color_discrete_map={'(?)':'lightgrey','EVP':'gold', 'SP':'#FF3030', 'PdA':'#EE3B3B', 'Grüne':'#A2CD5A','GLP':'#CAFF70','Die Mitte':'orange','FDP':'#104E8B','AL':'deeppink','SVP':'forestgreen', 'FL ZÜRI':'#8B864E','Volt':'#lightblue' }                
                 ## bei continuous scales (bei Zahlenwerten):
                , color_continuous_scale='cividis'
                #, color_continuous_midpoint=np.average(df['AnzBestWir'], weights=df['AnzBestWir'])  
                 ,height=500
                 ,width=1100                 
                )
fig.update_traces(root_color="grey")
fig.update_layout(margin = dict(t=50, l=25, r=250, b=25))
fig.show()

# %% [markdown]
# #### Abgebrochene Wohnungen nach Quartier, Kreis und Eigentümerart 2021

# %%
myTreemapAgg = data2betested.loc["2021"]\
    .groupby(['StichtagDatJahr', 'EigGruSort', 'EigGruLang','KreisLang','KreisSort', 'QuarLang','QuarSort' ]) \
    .agg( sum_WhgBestandRelevant=('WhgBestandRelevant', 'sum'), sum_WhgUmb=('WhgUmb', 'sum'), sum_WhgAbb=('WhgAbb', 'sum')) \
    .sort_values('StichtagDatJahr', ascending=True)

# %%
fig = px.treemap(myTreemapAgg.query('sum_WhgAbb >0').reset_index(), path=[px.Constant("Abgebrochene Wohnungen nach Quartier, Kreis und Eigentümerart 2021")
                                                                                      ,'KreisLang', 'QuarLang','EigGruLang']
                 , values='sum_WhgAbb'
                 , color='EigGruLang'
                 ## bei discrete scales (bei Klassen und Strings):                 
                 , color_discrete_map={'(?)':'lightgrey','EVP':'gold', 'SP':'#FF3030', 'PdA':'#EE3B3B', 'Grüne':'#A2CD5A','GLP':'#CAFF70','Die Mitte':'orange','FDP':'#104E8B','AL':'deeppink','SVP':'forestgreen', 'FL ZÜRI':'#8B864E','Volt':'#lightblue' }                
                 ## bei continuous scales (bei Zahlenwerten):
                , color_continuous_scale='cividis'
                #, color_continuous_midpoint=np.average(df['AnzBestWir'], weights=df['AnzBestWir'])  
                 ,height=500
                 ,width=1100                 
                )
fig.update_traces(root_color="grey")
fig.update_layout(margin = dict(t=50, l=25, r=250, b=25))
fig.show()

# %% [markdown]
# #### Umgebaute Wohnungen nach Kreis, Quartier und Eigentümerart 2021

# %%
#data2betested.dtypes

# %%
#myTreemapAgg.reset_index().head(3)

# %%
fig = px.treemap(myTreemapAgg.query('sum_WhgUmb >0').reset_index(), path=[px.Constant("Umgebaute Wohnungen nach Kreis, Quartier und Eigentümerart 2021")
                                                                                      ,'KreisLang', 'QuarLang','EigGruLang']
                 , values='sum_WhgUmb'
                 , color='EigGruLang'
                 ## bei discrete scales (bei Klassen und Strings):                 
                 , color_discrete_map={'(?)':'lightgrey','EVP':'gold', 'SP':'#FF3030', 'PdA':'#EE3B3B', 'Grüne':'#A2CD5A','GLP':'#CAFF70','Die Mitte':'orange','FDP':'#104E8B','AL':'deeppink','SVP':'forestgreen', 'FL ZÜRI':'#8B864E','Volt':'#lightblue' }                
                 ## bei continuous scales (bei Zahlenwerten):
                , color_continuous_scale='cividis'
                #, color_continuous_midpoint=np.average(df['AnzBestWir'], weights=df['AnzBestWir'])  
                 ,height=500
                 ,width=1100                 
                )
fig.update_traces(root_color="grey")
fig.update_layout(margin = dict(t=50, l=25, r=250, b=25))
fig.show()

# %%
#data2betested.dtypes

# %% [markdown]
# **Sharepoint als gecheckt markieren!**

# %% [markdown]
# Record auf Sharepoint: **[Link](https://kollaboration.intranet.stzh.ch/orga/ssz-produkte/Lists/SASA_Outputs/DispForm.aspx?ID=403&ContentTypeId=0x0100988EAF029F1EFE4CA675F53C32A5D53D01006DBC563E6FBE9E4EB6FDC780799752E1)**

# %% [markdown]
# ## ---------------------- hier Plausi beendet
#
# Liniendiagramm
# [Link zur Doku](https://altair-viz.github.io/gallery/multiline_highlight.html)

# %% [markdown]
# ### Test: Choroplethenkarte
# Importiere die Geodaten als GeoJSON

# %% [markdown]
# #### Stadtkreise

# %%
# Read abt. Geopandas https://geopandas.org/docs/user_guide/io.html
geojson_url_kreise = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Stadtkreise?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_stadtkreise_v"
adm_stadtkreise_v = gpd.read_file(geojson_url_kreise)

adm_stadtkreise_v.head(1)
# Out:
#                     id    kname  knr objid                                           geometry
# 0  adm_stadtkreise_v.6  Kreis 7    7     6  POLYGON ((8.54885 47.36602, 8.54901 47.36601, ...

# %% [markdown]
# #### Statistische Zonen

# %%
# Read abt. Geopandas https://geopandas.org/docs/user_guide/io.html
geojson_url_statzonen = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Statistische_Zonen?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_statzonen_map"
adm_statzonen_map = gpd.read_file(geojson_url_statzonen)

adm_statzonen_map.head(2)
# Out:
#                     id    kname  knr  objectid objid       qname  qnr   stzname  stznr  \
# 0  adm_statzonen_map.1  Kreis 7    7         1   154  Hirslanden   73  Hegibach   7303
# 1  adm_statzonen_map.2  Kreis 7    7         2    89  Hirslanden   73      Klus   7302
#
#                                             geometry
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...
# 1  POLYGON ((8.57281 47.35806, 8.57278 47.35807, ...

# %% [markdown]
# #### Statistische Quartiere

# %%
geojson_url_quartiere = "https://www.ogd.stadt-zuerich.ch/wfs/geoportal/Statistische_Quartiere?service=WFS&version=1.1.0&request=GetFeature&outputFormat=GeoJSON&typename=adm_statistische_quartiere_map"
df_adm_statistische_quartiere_map = gpd.read_file(geojson_url_quartiere)

df_adm_statistische_quartiere_map.head(2)
# Out:
#                                  id    kname  knr  objectid objid       qname  qnr  \
# 0  adm_statistische_quartiere_map.1  Kreis 7    7         1    34  Hirslanden   73
# 1  adm_statistische_quartiere_map.2  Kreis 8    8         2    33     Weinegg   83
#
#                                             geometry
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...
# 1  POLYGON ((8.55670 47.36405, 8.55672 47.36403, ...

# %% [markdown]
# ### Joins
# Joine die importierten statistischen Daten des aktuellen Jahres zum Geodatensatz:
#
# *Siehe dazu Doku zu [Geopandas](https://geopandas.org/docs/user_guide/mergingdata.html)*

# %%
data2betested.dtypes
# Out:
# StatZoneCd             int64
# StatZone              object
# QuarCd                 int64
# QuarLang              object
# KreisCd                int64
# KreisLang             object
# EigentumsartSort       int64
# Eigentumsart          object
# Whg_abgebrochen        int64
# Whg_fertigerstellt     int64
# dtype: object

# %%
myAgg = data2betested.loc["2021"]  \
    .groupby(['QuarLang', 'QuarCd']) \
    .agg(sum_Whg_abgebrochen=('Whg_abgebrochen', 'sum'),sum_Whg_fertigerstellt=('Whg_fertigerstellt', 'sum')) \
    .sort_values('sum_Whg_abgebrochen', ascending=False) 

myAgg.reset_index().head(1)
# Out:
#       QuarLang  QuarCd  sum_Whg_abgebrochen  sum_Whg_fertigerstellt
# 0  Albisrieden      91                  282                      89

# %%
# Rename attribute stznr to StatZoneSort, so the IDs have the same name
gdf_adm_statistische_quartiere_map = df_adm_statistische_quartiere_map[['geometry', 'qnr', 'qname', 'knr']].rename(columns={'qnr': 'QuarCd'})
gdf_adm_statistische_quartiere_map.head(1)
# Out:
#                                             geometry  QuarCd       qname  knr
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...      73  Hirslanden    7

# %%
# Merge with `merge` method on shared variable (stznr und StatZoneSort):
gdf_adm_statistische_quartiere_map_joined = gdf_adm_statistische_quartiere_map.merge(myAgg, on='QuarCd')
gdf_adm_statistische_quartiere_map_joined.head(2)
# Out:
#                                             geometry  QuarCd       qname  knr  \
# 0  POLYGON ((8.55670 47.36406, 8.55682 47.36410, ...      73  Hirslanden    7
# 1  POLYGON ((8.55670 47.36405, 8.55672 47.36403, ...      83     Weinegg    8
#
#    sum_Whg_abgebrochen  sum_Whg_fertigerstellt
# 0                   48                       2
# 1                    2                       0

# %%
# Plot by StatQuartiere
# Weitere Schemes: scheme='quantiles', scheme='fisherjenks', scheme='natural_breaks',

gdf_adm_statistische_quartiere_map_joined.plot(column='sum_Whg_fertigerstellt', cmap='viridis', scheme='natural_breaks', legend=True )
gdf_adm_statistische_quartiere_map_joined.plot(column='sum_Whg_abgebrochen', cmap='viridis', scheme='natural_breaks', legend=True )

#gdf_adm_statistische_quartiere_map_joined.plot(column='sum_Whg_abgebrochen', cmap='plasma', scheme='fisherjenks', legend=True )
#gdf_adm_statistische_quartiere_map_joined.plot(column='sum_Whg_fertigerstellt', cmap='cool', scheme='quantiles', legend=True )
#scheme werte: https://matplotlib.org/2.0.2/users/colormaps.html

#
#Neuere Gallerie: https://matplotlib.org/stable/gallery/index.html
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 1)

gdf_adm_statistische_quartiere_map_joined.plot(column='sum_Whg_abgebrochen', ax=ax, legend=True, legend_kwds={'label': "Anzahl abgebrochene Wohnungen 2021",'orientation': "horizontal"})
gdf_adm_statistische_quartiere_map_joined.plot(column='sum_Whg_fertigerstellt', ax=ax, legend=False, legend_kwds={'label': "Anzahl fertigerstellte Wohnungen 2021",'orientation': "horizontal"})

#gdf_adm_statistische_quartiere_map_joined.plot(column='sum_Whg_abgebrochen', cmap='viridis', scheme='natural_breaks', legend=True , ax=ax, legend_kwds={'label': "Anzahl Personen",'orientation': "horizontal"})
# Out:
# <AxesSubplot:>

# %% [markdown]
# Noch zu prüfen, folgendes schöne Beispiel: https://docs.bokeh.org/en/latest/docs/user_guide/interaction/legends.html
#
# Konkrete Beispiele von Bookeh in Jupyter NB: https://docs.bokeh.org/en/latest/docs/user_guide/jupyter.html

# %% [markdown]
# **Sharepoint als gecheckt markieren!**

# %% [markdown]
# Record auf Sharepoint: **[Link](https://kollaboration.intranet.stzh.ch/orga/ssz-produkte/Lists/SASA_Outputs/DispForm.aspx?ID=403&ContentTypeId=0x0100988EAF029F1EFE4CA675F53C32A5D53D01006DBC563E6FBE9E4EB6FDC780799752E1)**
